# %%
import torch
from torch.utils.data import Dataset, DataLoader
from diffusers import DDPMScheduler, UNet2DModel, AutoencoderKL
from pathlib import Path
import logging
from tqdm import tqdm
import torchvision.utils as vutils
from PIL import Image
import torchvision.transforms as T
import numpy as np

# %%
# !pip install -r /kaggle/input/codesa/requirements.txt

# %% [markdown]
# Preprocess Data

# %%
import os
import numpy as np
import cv2
from PIL import Image
from tqdm import tqdm
from pathlib import Path
import logging
import shutil

class DataPreprocessor:
    def __init__(self, input_dir, output_dir):
        self.input_dir = Path(input_dir)
        self.output_base = Path(output_dir)
        
        # Verify input directory exists
        if not self.input_dir.exists():
            raise FileNotFoundError(f"Input directory not found: {self.input_dir}")
        
        logging.info(f"Input directory: {self.input_dir}")
        logging.info(f"Output directory: {self.output_base}")
        
        # Create train/val/test splits
        self.splits = {
            'train': self.output_base / 'train',
            'val': self.output_base / 'val',
            'test': self.output_base / 'test'
        }
    
    def get_all_images(self):
        """Get all images from all class folders"""
        all_images = []
        # Iterate through all class folders
        for class_dir in self.input_dir.iterdir():
            if class_dir.is_dir():  # Make sure it's a directory
                logging.info(f"Found class directory: {class_dir.name}")
                # Get all images in this class directory
                class_images = list(class_dir.glob('*.jpg')) + list(class_dir.glob('*.png'))
                all_images.extend(class_images)
                logging.info(f"Found {len(class_images)} images in {class_dir.name}")
        
        return all_images

    def setup_directories(self):
        """Create all necessary directories"""
        created_dirs = []
        for split in self.splits.values():
            for subdir in ['clean', 'noisy', 'low_res', 'masked']:
                dir_path = split / subdir
                dir_path.mkdir(parents=True, exist_ok=True)
                created_dirs.append(str(dir_path))
        
        logging.info("Created directories:")
        for dir_path in created_dirs:
            logging.info(f"  - {dir_path}")
    
    def split_data(self, train_ratio=0.8, val_ratio=0.1, use_fraction=0.5):
        """Split data into train/val/test sets"""
        all_images = self.get_all_images()
        
        if not all_images:
            raise RuntimeError(f"No images found in {self.input_dir}")
        
        # Reduce dataset size
        num_samples = int(len(all_images) * use_fraction)
        all_images = all_images[:num_samples]  # Take only fraction of data
        
        logging.info(f"Using {num_samples} images out of {len(all_images)} total images")
        
        np.random.seed(42)  # For reproducibility
        np.random.shuffle(all_images)
        
        n_images = len(all_images)
        n_train = int(n_images * train_ratio)
        n_val = int(n_images * val_ratio)
        
        splits = {
            'train': all_images[:n_train],
            'val': all_images[n_train:n_train + n_val],
            'test': all_images[n_train + n_val:]
        }
        
        for split_name, split_images in splits.items():
            logging.info(f"{split_name} split: {len(split_images)} images")
        
        return splits

    def process_image(self, img_path, split_type):
        """Process a single image and save its variations"""
        try:
            # Create output filename (preserve class information in filename)
            class_name = img_path.parent.name
            new_filename = f"{class_name}_{img_path.name}"
            
            # Read and resize image
            original = Image.open(img_path)
            original = original.resize((256, 256), Image.Resampling.LANCZOS)
            img_array = np.array(original).astype(np.float32) / 255.0
            
            # Save clean image
            clean_path = self.splits[split_type] / 'clean' / new_filename
            original.save(clean_path)
            
            # Create noisy version
            noise = np.random.normal(0, 0.1, img_array.shape)
            noisy_img = np.clip(img_array + noise, 0, 1)
            noisy_img = (noisy_img * 255).astype(np.uint8)
            Image.fromarray(noisy_img).save(
                self.splits[split_type] / 'noisy' / new_filename
            )
            
            # Create low-resolution version
            low_res = cv2.resize(img_array, (64, 64))
            low_res = cv2.resize(low_res, (256, 256))
            low_res = (low_res * 255).astype(np.uint8)
            Image.fromarray(low_res).save(
                self.splits[split_type] / 'low_res' / new_filename
            )
            
            # Create masked version
            masked = img_array.copy()
            num_masks = np.random.randint(1, 4)
            for _ in range(num_masks):
                x1, x2 = sorted(np.random.randint(0, 256, 2))
                y1, y2 = sorted(np.random.randint(0, 256, 2))
                masked[y1:y2, x1:x2] = 0
            masked = (masked * 255).astype(np.uint8)
            Image.fromarray(masked).save(
                self.splits[split_type] / 'masked' / new_filename
            )
            
        except Exception as e:
            logging.error(f"Error processing {img_path}: {e}")
            raise

    def preprocess(self):
        """Run the entire preprocessing pipeline"""
        try:
            logging.info("Setting up directories...")
            self.setup_directories()
            
            logging.info("Splitting data...")
            splits = self.split_data()
            
            total_processed = 0
            # Process each split
            for split_type, images in splits.items():
                logging.info(f"Processing {split_type} split...")
                for img_path in tqdm(images, desc=f"Processing {split_type}"):
                    self.process_image(img_path, split_type)
                    total_processed += 1
            
            logging.info(f"Preprocessing complete. Processed {total_processed} images.")
            
            # Verify final counts
            for split_type in self.splits:
                for subdir in ['clean', 'noisy', 'low_res', 'masked']:
                    dir_path = self.splits[split_type] / subdir
                    file_count = len(list(dir_path.glob('*')))
                    logging.info(f"{split_type}/{subdir}: {file_count} files")
                    
        except Exception as e:
            logging.error(f"Preprocessing failed: {e}")
            raise

if __name__ == "__main__":
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )
    
    try:
        input_dir = '/kaggle/input/eurosat/EuroSAT_RGB'
        output_dir = '/kaggle/working/data/processed'
        
        logging.info(f"Starting preprocessing...")
        preprocessor = DataPreprocessor(input_dir, output_dir)
        preprocessor.preprocess()
        
    except Exception as e:
        logging.error(f"Failed to complete preprocessing: {e}")
        raise

# %%
pwd

# %%
mkdir data/preprocessed

# %%
ls

# %%
class RestorationDataset(Dataset):
    def __init__(self, root_dir, transform=None, task="noisy", image_size=256):
        self.root_dir = Path(root_dir)
        self.image_size = image_size
        self.transform = transform or self._get_default_transforms()
        self.task = task
        
        # Verify directory exists
        if not self.root_dir.exists():
            raise FileNotFoundError(f"Directory not found: {self.root_dir}")
            
        logging.info(f"Initializing dataset from {self.root_dir}")
        self.image_pairs = self._get_image_pairs()
        logging.info(f"Found {len(self.image_pairs)} image pairs")
        
    def _get_default_transforms(self):
        return T.Compose([
            T.Resize(self.image_size),
            T.RandomCrop(self.image_size),
            T.RandomHorizontalFlip(p=0.5),
            T.ToTensor(),
            T.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
        ])
    
    def _get_image_pairs(self):
        clean_dir = self.root_dir / 'clean'
        degraded_dir = self.root_dir / self.task
        
        # Check if directories exist
        if not clean_dir.exists():
            raise FileNotFoundError(f"Clean images directory not found: {clean_dir}")
        if not degraded_dir.exists():
            raise FileNotFoundError(f"Degraded images directory not found: {degraded_dir}")
            
        # Get all image files
        clean_images = list(clean_dir.glob('*.jpg')) + list(clean_dir.glob('*.png'))
        degraded_images = list(degraded_dir.glob('*.jpg')) + list(degraded_dir.glob('*.png'))
        
        logging.info(f"Found {len(clean_images)} clean images and {len(degraded_images)} degraded images")
        
        if not clean_images:
            raise ValueError(f"No images found in clean directory: {clean_dir}")
        if not degraded_images:
            raise ValueError(f"No images found in degraded directory: {degraded_dir}")
            
        # Match pairs
        pairs = list(zip(sorted(degraded_images), sorted(clean_images)))
        
        if not pairs:
            raise ValueError("No matching image pairs found")
            
        return pairs
    
    def __len__(self):
        """Return the total number of image pairs"""
        return len(self.image_pairs)
    
    def __getitem__(self, idx):
        """Return a specific image pair"""
        degraded_path, clean_path = self.image_pairs[idx]
        
        # Load images
        degraded_img = Image.open(degraded_path).convert('RGB')
        clean_img = Image.open(clean_path).convert('RGB')
        
        # Apply transforms
        if self.transform:
            # Use same random seed for both transforms to ensure same augmentation
            seed = torch.randint(0, 2**32, (1,)).item()
            
            torch.manual_seed(seed)
            degraded_img = self.transform(degraded_img)
            
            torch.manual_seed(seed)
            clean_img = self.transform(clean_img)
        
        return {
            'degraded': degraded_img,
            'clean': clean_img,
            'path': str(clean_path)
        }

# %%
# 2. The Latent Diffusion Model
class LatentDiffusionModel(torch.nn.Module):
    def __init__(self, config):
        super().__init__()
        
        # Load pretrained VAE
        self.vae = AutoencoderKL.from_pretrained(
            "stabilityai/sd-vae-ft-mse",
            torch_dtype=torch.float32
        )
        
        # Freeze VAE parameters
        for param in self.vae.parameters():
            param.requires_grad = False
            
        # Initialize UNet for latent diffusion
        latent_size = config.model.image_size // 8  # VAE downsamples by 8
        self.unet = UNet2DModel(
            sample_size=latent_size,
            in_channels=4,  # Latent space channels
            out_channels=4,  # Match input channels
            layers_per_block=config.model.num_res_blocks,
            block_out_channels=(128, 128, 256, 256),  # Changed this
            down_block_types=["DownBlock2D"] * 4,
            up_block_types=["UpBlock2D"] * 4,
            norm_num_groups=8,  # Changed this
            norm_eps=1e-6
        )
    
    def encode(self, x):
        return self.vae.encode(x).latent_dist.sample()
    
    def decode(self, z):
        return self.vae.decode(z).sample
    
    def forward(self, x, t):
        return self.unet(x, t).sample

# %%
import torch
from torch.utils.data import DataLoader
from diffusers import DDPMScheduler
import hydra
from omegaconf import DictConfig
from pathlib import Path
import logging
from tqdm import tqdm
import torchvision.utils as vutils

class LatentDiffusionTrainer:
    def __init__(self, config):
        self.config = config
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        logging.info(f"Using device: {self.device}")
        
        # Initialize model and move to device
        self.model = LatentDiffusionModel(config).to(self.device)
        
        # Initialize noise scheduler
        self.noise_scheduler = DDPMScheduler(
            num_train_timesteps=config.diffusion.num_diffusion_timesteps,
            beta_start=config.diffusion.beta_start,
            beta_end=config.diffusion.beta_end,
            beta_schedule=config.diffusion.beta_schedule
        )
        
        # Initialize optimizer
        self.optimizer = torch.optim.AdamW(
            self.model.unet.parameters(),
            lr=config.training.learning_rate
        )
        
        # Initialize learning rate scheduler
        self.lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            self.optimizer, mode='min', factor=0.5, patience=10, verbose=True
        )
        
        # Setup logging directory
        self.save_dir = Path("results")
        self.save_dir.mkdir(exist_ok=True)
        
    def train_step(self, clean_images):
        # First encode the clean images to latent space using VAE
        with torch.no_grad():
            clean_latents = self.model.encode(clean_images) * 0.18215
        
        # Sample noise and timesteps
        noise = torch.randn_like(clean_latents)
        timesteps = torch.randint(
            0, self.noise_scheduler.num_train_timesteps,
            (clean_latents.shape[0],), device=self.device
        ).long()
        
        # Add noise to latents
        noisy_latents = self.noise_scheduler.add_noise(
            clean_latents, noise, timesteps
        )
        
        # Predict noise
        noise_pred = self.model.unet(noisy_latents, timesteps)
        
        # Calculate loss
        loss = torch.nn.functional.mse_loss(noise_pred.sample, noise)
        
        # Optimize
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        return loss.item()  # Return scalar value

    def validation_step(self, clean_images):
        # Similar to train_step but without gradients
        with torch.no_grad():
            clean_latents = self.model.encode(clean_images) * 0.18215
            
            noise = torch.randn_like(clean_latents)
            timesteps = torch.randint(
                0, self.noise_scheduler.num_train_timesteps,
                (clean_latents.shape[0],), device=self.device
            ).long()
            
            noisy_latents = self.noise_scheduler.add_noise(
                clean_latents, noise, timesteps
            )
            
            noise_pred = self.model.unet(noisy_latents, timesteps)
            
            loss = torch.nn.functional.mse_loss(noise_pred.sample, noise)
            
            return loss.item()  # Return scalar value

    def validate(self, val_loader):
        self.model.eval()  # Set model to evaluation mode
        val_loss = 0
        
        # Create progress bar for validation
        val_pbar = tqdm(val_loader, 
                       desc="Validating",
                       leave=False,
                       position=1,
                       bar_format='{l_bar}{bar:10}{r_bar}{bar:-10b}')
        
        for batch in val_pbar:
            clean_images = batch['clean'].to(self.device)
            loss = self.validation_step(clean_images)
            val_loss += loss
            
            # Update validation progress bar
            val_pbar.set_postfix({'val_loss': f"{loss:.4f}"})
        
        avg_val_loss = val_loss / len(val_loader)
        return avg_val_loss

    def train(self):
        # Initialize datasets
        train_dataset = RestorationDataset(self.config.data.train_path, task=self.config.data.task)
        val_dataset = RestorationDataset(self.config.data.val_path, task=self.config.data.task)
        
        train_loader = DataLoader(
            train_dataset,
            batch_size=self.config.training.batch_size,
            shuffle=True,
            num_workers=self.config.training.num_workers
        )
        
        val_loader = DataLoader(
            val_dataset,
            batch_size=self.config.training.batch_size,
            shuffle=False,
            num_workers=self.config.training.num_workers
        )
        
        logging.info("Starting training...")
        best_val_loss = float('inf')
        
        for epoch in range(self.config.training.num_epochs):
            # Training phase
            self.model.train()
            train_loss = 0
            progress_bar = tqdm(train_loader, 
                              desc=f"Epoch {epoch}",
                              bar_format='{l_bar}{bar:10}{r_bar}{bar:-10b}')
            
            for step, batch in enumerate(progress_bar):
                clean_images = batch['clean'].to(self.device)
                loss = self.train_step(clean_images)
                train_loss += loss
                
                # Update progress bar
                progress_bar.set_postfix({
                    'loss': f"{loss:.4f}",
                    'lr': f"{self.optimizer.param_groups[0]['lr']:.6f}"
                })
                
                # Save sample restoration periodically
                if step % self.config.logging.sample_interval == 0:
                    self.save_sample_restoration(
                        batch['degraded'][:1],
                        epoch,
                        step
                    )
            
            avg_train_loss = train_loss / len(train_loader)
            logging.info(f"Epoch {epoch} - Train Loss: {avg_train_loss:.4f}")
            
            # Validation phase
            val_loss = self.validate(val_loader)
            logging.info(f"Epoch {epoch} - Validation Loss: {val_loss:.4f}")
            
            # Update learning rate
            self.lr_scheduler.step(val_loss)
            
            # Save best model
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                self.save_checkpoint(epoch, is_best=True)
            
            # Regular checkpoint saving
            if epoch % self.config.training.save_interval == 0:
                self.save_checkpoint(epoch)
                
    def save_sample_restoration(self, degraded_image, epoch, step):
        self.model.eval()
        with torch.no_grad():
            # Process image
            latents = self.model.encode(degraded_image.to(self.device))
            denoised_latents = self.denoise_latents(latents)
            restored_image = self.model.decode(denoised_latents)
            
            # Save image
            sample_dir = self.save_dir / "samples"
            sample_dir.mkdir(exist_ok=True)
            vutils.save_image(
                restored_image,
                sample_dir / f"restored_e{epoch}_s{step}.png",
                normalize=True
            )
        self.model.train()
    
    def denoise_latents(self, latents):
        # Gradually denoise latents using DDPM sampling
        for t in self.noise_scheduler.timesteps:
            noise_pred = self.model.unet(latents, t).sample
            latents = self.noise_scheduler.step(
                noise_pred, t, latents
            ).prev_sample
        return latents
    
    def save_checkpoint(self, epoch, is_best=False):
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'scheduler_state_dict': self.lr_scheduler.state_dict(),
        }
        
        # Save regular checkpoint
        checkpoint_path = self.save_dir / f"checkpoint_epoch_{epoch}.pt"
        torch.save(checkpoint, checkpoint_path)
        
        # Save best model
        if is_best:
            best_path = self.save_dir / "best_model.pt"
            torch.save(checkpoint, best_path)

# %%
# 4. Configuration
config = {
    'model': {
        'image_size': 256,
        'in_channels': 3,
        'model_channels': 128,
        'out_channels': 3,
        'num_res_blocks': 2,
        'attention_resolutions': [16, 8],
        'dropout': 0.0,
        'channel_mult': [1, 2, 3, 4],
        'conv_resample': True,
        'num_heads': 4
    },
    'training': {
        'batch_size': 8,
        'num_epochs': 1000,
        'learning_rate': 2e-4,
        'num_workers': 2,
        'save_interval': 1000,
        'eval_interval': 100
    },
    'diffusion': {
        'beta_schedule': 'linear',
        'beta_start': 0.0001,
        'beta_end': 0.02,
        'num_diffusion_timesteps': 1000
    },
    'data': {
        'train_path': "data/processed/train",
        'val_path': "data/processed/val",
        'test_path': "data/processed/test",
        'task': "noisy"  # Added this line - can be "noisy", "low_res", or "masked"
    },
    'logging': {
        'sample_interval': 500
    }
}

# Convert dict to an object for dot notation access
class Config:
    def __init__(self, config_dict):
        for key, value in config_dict.items():
            if isinstance(value, dict):
                setattr(self, key, Config(value))
            else:
                setattr(self, key, value)

config = Config(config)
# 5. Initialize and train
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

trainer = LatentDiffusionTrainer(config)
trainer.train()
# Out:
# Epoch 0:   0%|          | 0/1350 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/diffusers/configuration_utils.py:140: FutureWarning: Accessing config attribute `num_train_timesteps` directly via 'DDPMScheduler' object attribute is deprecated. Please access 'num_train_timesteps' over 'DDPMScheduler's config object instead, e.g. 'scheduler.config.num_train_timesteps'.
#   deprecate("direct config name access", "1.0.0", deprecation_message, standard_warn=False)
# Epoch 0: 100%|██████████| 1350/1350 [06:25<00:00,  3.50it/s, loss=0.2305, lr=0.000200]
#
# Validating:   0%|          | 0/169 [00:00<?, ?it/s]
# Validating:   0%|          | 0/169 [00:00<?, ?it/s, val_loss=0.0887]
# Validating:   1%|          | 1/169 [00:00<00:59,  2.80it/s, val_loss=0.0887]
# Validating:   1%|          | 1/169 [00:00<00:59,  2.80it/s, val_loss=0.0477]
# Validating:   1%|          | 2/169 [00:00<00:47,  3.55it/s, val_loss=0.0477]
# Validating:   1%|          | 2/169 [00:00<00:47,  3.55it/s, val_loss=0.0483]
# Validating:   2%|▏         | 3/169 [00:00<00:42,  3.88it/s, val_loss=0.0483]
# Validating:   2%|▏         | 3/169 [00:01<00:42,  3.88it/s, val_loss=0.0748]
# Validating:   2%|▏         | 4/169 [00:01<00:40,  4.07it/s, val_loss=0.0748]
# Validating:   2%|▏         | 4/169 [00:01<00:40,  4.07it/s, val_loss=0.0494]
# Validating:   3%|▎         | 5/169 [00:01<00:39,  4.16it/s, val_loss=0.0494]
# Validating:   3%|▎         | 5/169 [00:01<00:39,  4.16it/s, val_loss=0.1077]
# Validating:   4%|▎         | 6/169 [00:01<00:38,  4.22it/s, val_loss=0.1077]
# Validating:   4%|▎         | 6/169 [00:01<00:38,  4.22it/s, val_loss=0.0473]
# Validating:   4%|▍         | 7/169 [00:01<00:38,  4.26it/s, val_loss=0.0473]
# Validating:   4%|▍         | 7/169 [00:01<00:38,  4.26it/s, val_loss=0.2711]
# Validating:   5%|▍         | 8/169 [00:01<00:37,  4.28it/s, val_loss=0.2711]
# Validating:   5%|▍         | 8/169 [00:02<00:37,  4.28it/s, val_loss=0.1936]
# Validating:   5%|▌         | 9/169 [00:02<00:37,  4.31it/s, val_loss=0.1936]
# Validating:   5%|▌         | 9/169 [00:02<00:37,  4.31it/s, val_loss=0.0861]
# Validating:   6%|▌         | 10/169 [00:02<00:36,  4.33it/s, val_loss=0.0861]
# Validating:   6%|▌         | 10/169 [00:02<00:36,  4.33it/s, val_loss=0.0755]
# Validating:   7%|▋         | 11/169 [00:02<00:36,  4.34it/s, val_loss=0.0755]
# Validating:   7%|▋         | 11/169 [00:02<00:36,  4.34it/s, val_loss=0.1369]
# Validating:   7%|▋         | 12/169 [00:02<00:35,  4.36it/s, val_loss=0.1369]
# Validating:   7%|▋         | 12/169 [00:03<00:35,  4.36it/s, val_loss=0.2614]
# Validating:   8%|▊         | 13/169 [00:03<00:35,  4.36it/s, val_loss=0.2614]
# Validating:   8%|▊         | 13/169 [00:03<00:35,  4.36it/s, val_loss=0.0458]
# Validating:   8%|▊         | 14/169 [00:03<00:35,  4.37it/s, val_loss=0.0458]
# Validating:   8%|▊         | 14/169 [00:03<00:35,  4.37it/s, val_loss=0.0971]
# Validating:   9%|▉         | 15/169 [00:03<00:35,  4.35it/s, val_loss=0.0971]
# Validating:   9%|▉         | 15/169 [00:03<00:35,  4.35it/s, val_loss=0.0735]
# Validating:   9%|▉         | 16/169 [00:03<00:35,  4.35it/s, val_loss=0.0735]
# Validating:   9%|▉         | 16/169 [00:04<00:35,  4.35it/s, val_loss=0.3249]
# Validating:  10%|█         | 17/169 [00:04<00:34,  4.36it/s, val_loss=0.3249]
# Validating:  10%|█         | 17/169 [00:04<00:34,  4.36it/s, val_loss=0.1144]
# Validating:  11%|█         | 18/169 [00:04<00:34,  4.37it/s, val_loss=0.1144]
# Validating:  11%|█         | 18/169 [00:04<00:34,  4.37it/s, val_loss=0.0515]
# Validating:  11%|█         | 19/169 [00:04<00:34,  4.38it/s, val_loss=0.0515]
# Validating:  11%|█         | 19/169 [00:04<00:34,  4.38it/s, val_loss=0.0882]
# Validating:  12%|█▏        | 20/169 [00:04<00:34,  4.37it/s, val_loss=0.0882]
# Validating:  12%|█▏        | 20/169 [00:04<00:34,  4.37it/s, val_loss=0.1595]
# Validating:  12%|█▏        | 21/169 [00:04<00:33,  4.36it/s, val_loss=0.1595]
# Validating:  12%|█▏        | 21/169 [00:05<00:33,  4.36it/s, val_loss=0.0662]
# Validating:  13%|█▎        | 22/169 [00:05<00:33,  4.36it/s, val_loss=0.0662]
# Validating:  13%|█▎        | 22/169 [00:05<00:33,  4.36it/s, val_loss=0.2914]
# Validating:  14%|█▎        | 23/169 [00:05<00:33,  4.37it/s, val_loss=0.2914]
# Validating:  14%|█▎        | 23/169 [00:05<00:33,  4.37it/s, val_loss=0.2374]
# Validating:  14%|█▍        | 24/169 [00:05<00:33,  4.35it/s, val_loss=0.2374]
# Validating:  14%|█▍        | 24/169 [00:05<00:33,  4.35it/s, val_loss=0.1463]
# Validating:  15%|█▍        | 25/169 [00:05<00:33,  4.36it/s, val_loss=0.1463]
# Validating:  15%|█▍        | 25/169 [00:06<00:33,  4.36it/s, val_loss=0.1858]
# Validating:  15%|█▌        | 26/169 [00:06<00:32,  4.37it/s, val_loss=0.1858]
# Validating:  15%|█▌        | 26/169 [00:06<00:32,  4.37it/s, val_loss=0.0892]
# Validating:  16%|█▌        | 27/169 [00:06<00:32,  4.37it/s, val_loss=0.0892]
# Validating:  16%|█▌        | 27/169 [00:06<00:32,  4.37it/s, val_loss=0.1608]
# Validating:  17%|█▋        | 28/169 [00:06<00:32,  4.37it/s, val_loss=0.1608]
# Validating:  17%|█▋        | 28/169 [00:06<00:32,  4.37it/s, val_loss=0.0520]
# Validating:  17%|█▋        | 29/169 [00:06<00:32,  4.36it/s, val_loss=0.0520]
# Validating:  17%|█▋        | 29/169 [00:07<00:32,  4.36it/s, val_loss=0.1815]
# Validating:  18%|█▊        | 30/169 [00:07<00:31,  4.36it/s, val_loss=0.1815]
# Validating:  18%|█▊        | 30/169 [00:07<00:31,  4.36it/s, val_loss=0.1123]
# Validating:  18%|█▊        | 31/169 [00:07<00:31,  4.35it/s, val_loss=0.1123]
# Validating:  18%|█▊        | 31/169 [00:07<00:31,  4.35it/s, val_loss=0.2034]
# Validating:  19%|█▉        | 32/169 [00:07<00:31,  4.35it/s, val_loss=0.2034]
# Validating:  19%|█▉        | 32/169 [00:07<00:31,  4.35it/s, val_loss=0.1416]
# Validating:  20%|█▉        | 33/169 [00:07<00:31,  4.35it/s, val_loss=0.1416]
# Validating:  20%|█▉        | 33/169 [00:07<00:31,  4.35it/s, val_loss=0.1211]
# Validating:  20%|██        | 34/169 [00:07<00:30,  4.36it/s, val_loss=0.1211]
# Validating:  20%|██        | 34/169 [00:08<00:30,  4.36it/s, val_loss=0.0737]
# Validating:  21%|██        | 35/169 [00:08<00:30,  4.36it/s, val_loss=0.0737]
# Validating:  21%|██        | 35/169 [00:08<00:30,  4.36it/s, val_loss=0.1942]
# Validating:  21%|██▏       | 36/169 [00:08<00:30,  4.36it/s, val_loss=0.1942]
# Validating:  21%|██▏       | 36/169 [00:08<00:30,  4.36it/s, val_loss=0.1664]
# Validating:  22%|██▏       | 37/169 [00:08<00:30,  4.34it/s, val_loss=0.1664]
# Validating:  22%|██▏       | 37/169 [00:08<00:30,  4.34it/s, val_loss=0.2441]
# Validating:  22%|██▏       | 38/169 [00:08<00:30,  4.35it/s, val_loss=0.2441]
# Validating:  22%|██▏       | 38/169 [00:09<00:30,  4.35it/s, val_loss=0.0804]
# Validating:  23%|██▎       | 39/169 [00:09<00:29,  4.35it/s, val_loss=0.0804]
# Validating:  23%|██▎       | 39/169 [00:09<00:29,  4.35it/s, val_loss=0.0829]
# Validating:  24%|██▎       | 40/169 [00:09<00:29,  4.34it/s, val_loss=0.0829]
# Validating:  24%|██▎       | 40/169 [00:09<00:29,  4.34it/s, val_loss=0.1359]
# Validating:  24%|██▍       | 41/169 [00:09<00:29,  4.34it/s, val_loss=0.1359]
# Validating:  24%|██▍       | 41/169 [00:09<00:29,  4.34it/s, val_loss=0.2050]
# Validating:  25%|██▍       | 42/169 [00:09<00:29,  4.35it/s, val_loss=0.2050]
# Validating:  25%|██▍       | 42/169 [00:09<00:29,  4.35it/s, val_loss=0.1456]
# Validating:  25%|██▌       | 43/169 [00:09<00:28,  4.35it/s, val_loss=0.1456]
# Validating:  25%|██▌       | 43/169 [00:10<00:28,  4.35it/s, val_loss=0.3043]
# Validating:  26%|██▌       | 44/169 [00:10<00:28,  4.36it/s, val_loss=0.3043]
# Validating:  26%|██▌       | 44/169 [00:10<00:28,  4.36it/s, val_loss=0.3073]
# Validating:  27%|██▋       | 45/169 [00:10<00:28,  4.35it/s, val_loss=0.3073]
# Validating:  27%|██▋       | 45/169 [00:10<00:28,  4.35it/s, val_loss=0.1110]
# Validating:  27%|██▋       | 46/169 [00:10<00:28,  4.35it/s, val_loss=0.1110]
# Validating:  27%|██▋       | 46/169 [00:10<00:28,  4.35it/s, val_loss=0.0517]
# Validating:  28%|██▊       | 47/169 [00:10<00:28,  4.34it/s, val_loss=0.0517]
# Validating:  28%|██▊       | 47/169 [00:11<00:28,  4.34it/s, val_loss=0.2264]
# Validating:  28%|██▊       | 48/169 [00:11<00:27,  4.34it/s, val_loss=0.2264]
# Validating:  28%|██▊       | 48/169 [00:11<00:27,  4.34it/s, val_loss=0.1943]
# Validating:  29%|██▉       | 49/169 [00:11<00:27,  4.33it/s, val_loss=0.1943]
# Validating:  29%|██▉       | 49/169 [00:11<00:27,  4.33it/s, val_loss=0.0919]
# Validating:  30%|██▉       | 50/169 [00:11<00:27,  4.34it/s, val_loss=0.0919]
# Validating:  30%|██▉       | 50/169 [00:11<00:27,  4.34it/s, val_loss=0.0679]
# Validating:  30%|███       | 51/169 [00:11<00:27,  4.33it/s, val_loss=0.0679]
# Validating:  30%|███       | 51/169 [00:12<00:27,  4.33it/s, val_loss=0.2640]
# Validating:  31%|███       | 52/169 [00:12<00:26,  4.34it/s, val_loss=0.2640]
# Validating:  31%|███       | 52/169 [00:12<00:26,  4.34it/s, val_loss=0.1957]
# Validating:  31%|███▏      | 53/169 [00:12<00:26,  4.34it/s, val_loss=0.1957]
# Validating:  31%|███▏      | 53/169 [00:12<00:26,  4.34it/s, val_loss=0.1840]
# Validating:  32%|███▏      | 54/169 [00:12<00:26,  4.35it/s, val_loss=0.1840]
# Validating:  32%|███▏      | 54/169 [00:12<00:26,  4.35it/s, val_loss=0.2021]
# Validating:  33%|███▎      | 55/169 [00:12<00:26,  4.35it/s, val_loss=0.2021]
# Validating:  33%|███▎      | 55/169 [00:12<00:26,  4.35it/s, val_loss=0.2543]
# Validating:  33%|███▎      | 56/169 [00:12<00:26,  4.34it/s, val_loss=0.2543]
# Validating:  33%|███▎      | 56/169 [00:13<00:26,  4.34it/s, val_loss=0.0873]
# Validating:  34%|███▎      | 57/169 [00:13<00:25,  4.35it/s, val_loss=0.0873]
# Validating:  34%|███▎      | 57/169 [00:13<00:25,  4.35it/s, val_loss=0.2078]
# Validating:  34%|███▍      | 58/169 [00:13<00:25,  4.36it/s, val_loss=0.2078]
# Validating:  34%|███▍      | 58/169 [00:13<00:25,  4.36it/s, val_loss=0.1130]
# Validating:  35%|███▍      | 59/169 [00:13<00:25,  4.36it/s, val_loss=0.1130]
# Validating:  35%|███▍      | 59/169 [00:13<00:25,  4.36it/s, val_loss=0.1584]
# Validating:  36%|███▌      | 60/169 [00:13<00:24,  4.37it/s, val_loss=0.1584]
# Validating:  36%|███▌      | 60/169 [00:14<00:24,  4.37it/s, val_loss=0.1534]
# Validating:  36%|███▌      | 61/169 [00:14<00:24,  4.37it/s, val_loss=0.1534]
# Validating:  36%|███▌      | 61/169 [00:14<00:24,  4.37it/s, val_loss=0.0851]
# Validating:  37%|███▋      | 62/169 [00:14<00:24,  4.37it/s, val_loss=0.0851]
# Validating:  37%|███▋      | 62/169 [00:14<00:24,  4.37it/s, val_loss=0.1462]
# Validating:  37%|███▋      | 63/169 [00:14<00:24,  4.37it/s, val_loss=0.1462]
# Validating:  37%|███▋      | 63/169 [00:14<00:24,  4.37it/s, val_loss=0.1253]
# Validating:  38%|███▊      | 64/169 [00:14<00:24,  4.37it/s, val_loss=0.1253]
# Validating:  38%|███▊      | 64/169 [00:15<00:24,  4.37it/s, val_loss=0.2069]
# Validating:  38%|███▊      | 65/169 [00:15<00:23,  4.38it/s, val_loss=0.2069]
# Validating:  38%|███▊      | 65/169 [00:15<00:23,  4.38it/s, val_loss=0.0382]
# Validating:  39%|███▉      | 66/169 [00:15<00:23,  4.37it/s, val_loss=0.0382]
# Validating:  39%|███▉      | 66/169 [00:15<00:23,  4.37it/s, val_loss=0.0330]
# Validating:  40%|███▉      | 67/169 [00:15<00:23,  4.37it/s, val_loss=0.0330]
# Validating:  40%|███▉      | 67/169 [00:15<00:23,  4.37it/s, val_loss=0.1729]
# Validating:  40%|████      | 68/169 [00:15<00:23,  4.37it/s, val_loss=0.1729]
# Validating:  40%|████      | 68/169 [00:15<00:23,  4.37it/s, val_loss=0.0252]
# Validating:  41%|████      | 69/169 [00:15<00:22,  4.36it/s, val_loss=0.0252]
# Validating:  41%|████      | 69/169 [00:16<00:22,  4.36it/s, val_loss=0.0575]
# Validating:  41%|████▏     | 70/169 [00:16<00:22,  4.36it/s, val_loss=0.0575]
# Validating:  41%|████▏     | 70/169 [00:16<00:22,  4.36it/s, val_loss=0.1425]
# Validating:  42%|████▏     | 71/169 [00:16<00:22,  4.38it/s, val_loss=0.1425]
# Validating:  42%|████▏     | 71/169 [00:16<00:22,  4.38it/s, val_loss=0.0810]
# Validating:  43%|████▎     | 72/169 [00:16<00:22,  4.37it/s, val_loss=0.0810]
# Validating:  43%|████▎     | 72/169 [00:16<00:22,  4.37it/s, val_loss=0.0479]
# Validating:  43%|████▎     | 73/169 [00:16<00:21,  4.37it/s, val_loss=0.0479]
# Validating:  43%|████▎     | 73/169 [00:17<00:21,  4.37it/s, val_loss=0.0742]
# Validating:  44%|████▍     | 74/169 [00:17<00:21,  4.36it/s, val_loss=0.0742]
# Validating:  44%|████▍     | 74/169 [00:17<00:21,  4.36it/s, val_loss=0.0735]
# Validating:  44%|████▍     | 75/169 [00:17<00:21,  4.36it/s, val_loss=0.0735]
# Validating:  44%|████▍     | 75/169 [00:17<00:21,  4.36it/s, val_loss=0.2240]
# Validating:  45%|████▍     | 76/169 [00:17<00:21,  4.36it/s, val_loss=0.2240]
# Validating:  45%|████▍     | 76/169 [00:17<00:21,  4.36it/s, val_loss=0.3231]
# Validating:  46%|████▌     | 77/169 [00:17<00:21,  4.36it/s, val_loss=0.3231]
# Validating:  46%|████▌     | 77/169 [00:18<00:21,  4.36it/s, val_loss=0.1502]
# Validating:  46%|████▌     | 78/169 [00:18<00:20,  4.36it/s, val_loss=0.1502]
# Validating:  46%|████▌     | 78/169 [00:18<00:20,  4.36it/s, val_loss=0.0673]
# Validating:  47%|████▋     | 79/169 [00:18<00:20,  4.37it/s, val_loss=0.0673]
# Validating:  47%|████▋     | 79/169 [00:18<00:20,  4.37it/s, val_loss=0.0408]
# Validating:  47%|████▋     | 80/169 [00:18<00:20,  4.38it/s, val_loss=0.0408]
# Validating:  47%|████▋     | 80/169 [00:18<00:20,  4.38it/s, val_loss=0.1410]
# Validating:  48%|████▊     | 81/169 [00:18<00:20,  4.38it/s, val_loss=0.1410]
# Validating:  48%|████▊     | 81/169 [00:18<00:20,  4.38it/s, val_loss=0.1331]
# Validating:  49%|████▊     | 82/169 [00:18<00:19,  4.36it/s, val_loss=0.1331]
# Validating:  49%|████▊     | 82/169 [00:19<00:19,  4.36it/s, val_loss=0.1136]
# Validating:  49%|████▉     | 83/169 [00:19<00:19,  4.36it/s, val_loss=0.1136]
# Validating:  49%|████▉     | 83/169 [00:19<00:19,  4.36it/s, val_loss=0.1158]
# Validating:  50%|████▉     | 84/169 [00:19<00:19,  4.36it/s, val_loss=0.1158]
# Validating:  50%|████▉     | 84/169 [00:19<00:19,  4.36it/s, val_loss=0.0711]
# Validating:  50%|█████     | 85/169 [00:19<00:19,  4.35it/s, val_loss=0.0711]
# Validating:  50%|█████     | 85/169 [00:19<00:19,  4.35it/s, val_loss=0.1516]
# Validating:  51%|█████     | 86/169 [00:19<00:19,  4.35it/s, val_loss=0.1516]
# Validating:  51%|█████     | 86/169 [00:20<00:19,  4.35it/s, val_loss=0.1276]
# Validating:  51%|█████▏    | 87/169 [00:20<00:18,  4.35it/s, val_loss=0.1276]
# Validating:  51%|█████▏    | 87/169 [00:20<00:18,  4.35it/s, val_loss=0.0744]
# Validating:  52%|█████▏    | 88/169 [00:20<00:18,  4.35it/s, val_loss=0.0744]
# Validating:  52%|█████▏    | 88/169 [00:20<00:18,  4.35it/s, val_loss=0.3879]
# Validating:  53%|█████▎    | 89/169 [00:20<00:18,  4.35it/s, val_loss=0.3879]
# Validating:  53%|█████▎    | 89/169 [00:20<00:18,  4.35it/s, val_loss=0.1276]
# Validating:  53%|█████▎    | 90/169 [00:20<00:18,  4.34it/s, val_loss=0.1276]
# Validating:  53%|█████▎    | 90/169 [00:21<00:18,  4.34it/s, val_loss=0.1362]
# Validating:  54%|█████▍    | 91/169 [00:21<00:17,  4.34it/s, val_loss=0.1362]
# Validating:  54%|█████▍    | 91/169 [00:21<00:17,  4.34it/s, val_loss=0.0229]
# Validating:  54%|█████▍    | 92/169 [00:21<00:17,  4.34it/s, val_loss=0.0229]
# Validating:  54%|█████▍    | 92/169 [00:21<00:17,  4.34it/s, val_loss=0.0951]
# Validating:  55%|█████▌    | 93/169 [00:21<00:17,  4.34it/s, val_loss=0.0951]
# Validating:  55%|█████▌    | 93/169 [00:21<00:17,  4.34it/s, val_loss=0.2162]
# Validating:  56%|█████▌    | 94/169 [00:21<00:17,  4.35it/s, val_loss=0.2162]
# Validating:  56%|█████▌    | 94/169 [00:21<00:17,  4.35it/s, val_loss=0.1290]
# Validating:  56%|█████▌    | 95/169 [00:21<00:16,  4.35it/s, val_loss=0.1290]
# Validating:  56%|█████▌    | 95/169 [00:22<00:16,  4.35it/s, val_loss=0.3089]
# Validating:  57%|█████▋    | 96/169 [00:22<00:16,  4.34it/s, val_loss=0.3089]
# Validating:  57%|█████▋    | 96/169 [00:22<00:16,  4.34it/s, val_loss=0.2421]
# Validating:  57%|█████▋    | 97/169 [00:22<00:16,  4.34it/s, val_loss=0.2421]
# Validating:  57%|█████▋    | 97/169 [00:22<00:16,  4.34it/s, val_loss=0.0269]
# Validating:  58%|█████▊    | 98/169 [00:22<00:16,  4.35it/s, val_loss=0.0269]
# Validating:  58%|█████▊    | 98/169 [00:22<00:16,  4.35it/s, val_loss=0.0225]
# Validating:  59%|█████▊    | 99/169 [00:22<00:16,  4.34it/s, val_loss=0.0225]
# Validating:  59%|█████▊    | 99/169 [00:23<00:16,  4.34it/s, val_loss=0.2655]
# Validating:  59%|█████▉    | 100/169 [00:23<00:15,  4.35it/s, val_loss=0.2655]
# Validating:  59%|█████▉    | 100/169 [00:23<00:15,  4.35it/s, val_loss=0.1326]
# Validating:  60%|█████▉    | 101/169 [00:23<00:15,  4.35it/s, val_loss=0.1326]
# Validating:  60%|█████▉    | 101/169 [00:23<00:15,  4.35it/s, val_loss=0.2106]
# Validating:  60%|██████    | 102/169 [00:23<00:15,  4.35it/s, val_loss=0.2106]
# Validating:  60%|██████    | 102/169 [00:23<00:15,  4.35it/s, val_loss=0.2819]
# Validating:  61%|██████    | 103/169 [00:23<00:15,  4.35it/s, val_loss=0.2819]
# Validating:  61%|██████    | 103/169 [00:23<00:15,  4.35it/s, val_loss=0.1516]
# Validating:  62%|██████▏   | 104/169 [00:23<00:14,  4.35it/s, val_loss=0.1516]
# Validating:  62%|██████▏   | 104/169 [00:24<00:14,  4.35it/s, val_loss=0.2796]
# Validating:  62%|██████▏   | 105/169 [00:24<00:14,  4.35it/s, val_loss=0.2796]
# Validating:  62%|██████▏   | 105/169 [00:24<00:14,  4.35it/s, val_loss=0.3072]
# Validating:  63%|██████▎   | 106/169 [00:24<00:14,  4.35it/s, val_loss=0.3072]
# Validating:  63%|██████▎   | 106/169 [00:24<00:14,  4.35it/s, val_loss=0.1775]
# Validating:  63%|██████▎   | 107/169 [00:24<00:14,  4.34it/s, val_loss=0.1775]
# Validating:  63%|██████▎   | 107/169 [00:24<00:14,  4.34it/s, val_loss=0.0774]
# Validating:  64%|██████▍   | 108/169 [00:24<00:14,  4.35it/s, val_loss=0.0774]
# Validating:  64%|██████▍   | 108/169 [00:25<00:14,  4.35it/s, val_loss=0.0938]
# Validating:  64%|██████▍   | 109/169 [00:25<00:13,  4.34it/s, val_loss=0.0938]
# Validating:  64%|██████▍   | 109/169 [00:25<00:13,  4.34it/s, val_loss=0.0548]
# Validating:  65%|██████▌   | 110/169 [00:25<00:13,  4.35it/s, val_loss=0.0548]
# Validating:  65%|██████▌   | 110/169 [00:25<00:13,  4.35it/s, val_loss=0.1570]
# Validating:  66%|██████▌   | 111/169 [00:25<00:13,  4.35it/s, val_loss=0.1570]
# Validating:  66%|██████▌   | 111/169 [00:25<00:13,  4.35it/s, val_loss=0.0685]
# Validating:  66%|██████▋   | 112/169 [00:25<00:13,  4.36it/s, val_loss=0.0685]
# Validating:  66%|██████▋   | 112/169 [00:26<00:13,  4.36it/s, val_loss=0.1362]
# Validating:  67%|██████▋   | 113/169 [00:26<00:12,  4.37it/s, val_loss=0.1362]
# Validating:  67%|██████▋   | 113/169 [00:26<00:12,  4.37it/s, val_loss=0.1407]
# Validating:  67%|██████▋   | 114/169 [00:26<00:12,  4.37it/s, val_loss=0.1407]
# Validating:  67%|██████▋   | 114/169 [00:26<00:12,  4.37it/s, val_loss=0.1825]
# Validating:  68%|██████▊   | 115/169 [00:26<00:12,  4.37it/s, val_loss=0.1825]
# Validating:  68%|██████▊   | 115/169 [00:26<00:12,  4.37it/s, val_loss=0.0999]
# Validating:  69%|██████▊   | 116/169 [00:26<00:12,  4.37it/s, val_loss=0.0999]
# Validating:  69%|██████▊   | 116/169 [00:26<00:12,  4.37it/s, val_loss=0.2298]
# Validating:  69%|██████▉   | 117/169 [00:26<00:11,  4.36it/s, val_loss=0.2298]
# Validating:  69%|██████▉   | 117/169 [00:27<00:11,  4.36it/s, val_loss=0.0334]
# Validating:  70%|██████▉   | 118/169 [00:27<00:11,  4.35it/s, val_loss=0.0334]
# Validating:  70%|██████▉   | 118/169 [00:27<00:11,  4.35it/s, val_loss=0.1696]
# Validating:  70%|███████   | 119/169 [00:27<00:11,  4.35it/s, val_loss=0.1696]
# Validating:  70%|███████   | 119/169 [00:27<00:11,  4.35it/s, val_loss=0.0243]
# Validating:  71%|███████   | 120/169 [00:27<00:11,  4.33it/s, val_loss=0.0243]
# Validating:  71%|███████   | 120/169 [00:27<00:11,  4.33it/s, val_loss=0.0426]
# Validating:  72%|███████▏  | 121/169 [00:27<00:11,  4.34it/s, val_loss=0.0426]
# Validating:  72%|███████▏  | 121/169 [00:28<00:11,  4.34it/s, val_loss=0.2346]
# Validating:  72%|███████▏  | 122/169 [00:28<00:10,  4.35it/s, val_loss=0.2346]
# Validating:  72%|███████▏  | 122/169 [00:28<00:10,  4.35it/s, val_loss=0.1578]
# Validating:  73%|███████▎  | 123/169 [00:28<00:10,  4.34it/s, val_loss=0.1578]
# Validating:  73%|███████▎  | 123/169 [00:28<00:10,  4.34it/s, val_loss=0.2459]
# Validating:  73%|███████▎  | 124/169 [00:28<00:10,  4.34it/s, val_loss=0.2459]
# Validating:  73%|███████▎  | 124/169 [00:28<00:10,  4.34it/s, val_loss=0.1727]
# Validating:  74%|███████▍  | 125/169 [00:28<00:10,  4.34it/s, val_loss=0.1727]
# Validating:  74%|███████▍  | 125/169 [00:29<00:10,  4.34it/s, val_loss=0.2352]
# Validating:  75%|███████▍  | 126/169 [00:29<00:09,  4.35it/s, val_loss=0.2352]
# Validating:  75%|███████▍  | 126/169 [00:29<00:09,  4.35it/s, val_loss=0.0864]
# Validating:  75%|███████▌  | 127/169 [00:29<00:09,  4.35it/s, val_loss=0.0864]
# Validating:  75%|███████▌  | 127/169 [00:29<00:09,  4.35it/s, val_loss=0.0284]
# Validating:  76%|███████▌  | 128/169 [00:29<00:09,  4.35it/s, val_loss=0.0284]
# Validating:  76%|███████▌  | 128/169 [00:29<00:09,  4.35it/s, val_loss=0.2144]
# Validating:  76%|███████▋  | 129/169 [00:29<00:09,  4.34it/s, val_loss=0.2144]
# Validating:  76%|███████▋  | 129/169 [00:29<00:09,  4.34it/s, val_loss=0.0404]
# Validating:  77%|███████▋  | 130/169 [00:29<00:08,  4.34it/s, val_loss=0.0404]
# Validating:  77%|███████▋  | 130/169 [00:30<00:08,  4.34it/s, val_loss=0.0255]
# Validating:  78%|███████▊  | 131/169 [00:30<00:08,  4.36it/s, val_loss=0.0255]
# Validating:  78%|███████▊  | 131/169 [00:30<00:08,  4.36it/s, val_loss=0.2733]
# Validating:  78%|███████▊  | 132/169 [00:30<00:08,  4.36it/s, val_loss=0.2733]
# Validating:  78%|███████▊  | 132/169 [00:30<00:08,  4.36it/s, val_loss=0.1090]
# Validating:  79%|███████▊  | 133/169 [00:30<00:08,  4.37it/s, val_loss=0.1090]
# Validating:  79%|███████▊  | 133/169 [00:30<00:08,  4.37it/s, val_loss=0.1053]
# Validating:  79%|███████▉  | 134/169 [00:30<00:08,  4.37it/s, val_loss=0.1053]
# Validating:  79%|███████▉  | 134/169 [00:31<00:08,  4.37it/s, val_loss=0.0339]
# Validating:  80%|███████▉  | 135/169 [00:31<00:07,  4.37it/s, val_loss=0.0339]
# Validating:  80%|███████▉  | 135/169 [00:31<00:07,  4.37it/s, val_loss=0.2509]
# Validating:  80%|████████  | 136/169 [00:31<00:07,  4.37it/s, val_loss=0.2509]
# Validating:  80%|████████  | 136/169 [00:31<00:07,  4.37it/s, val_loss=0.1590]
# Validating:  81%|████████  | 137/169 [00:31<00:07,  4.35it/s, val_loss=0.1590]
# Validating:  81%|████████  | 137/169 [00:31<00:07,  4.35it/s, val_loss=0.1266]
# Validating:  82%|████████▏ | 138/169 [00:31<00:07,  4.35it/s, val_loss=0.1266]
# Validating:  82%|████████▏ | 138/169 [00:32<00:07,  4.35it/s, val_loss=0.1259]
# Validating:  82%|████████▏ | 139/169 [00:32<00:06,  4.33it/s, val_loss=0.1259]
# Validating:  82%|████████▏ | 139/169 [00:32<00:06,  4.33it/s, val_loss=0.0104]
# Validating:  83%|████████▎ | 140/169 [00:32<00:06,  4.34it/s, val_loss=0.0104]
# Validating:  83%|████████▎ | 140/169 [00:32<00:06,  4.34it/s, val_loss=0.0545]
# Validating:  83%|████████▎ | 141/169 [00:32<00:06,  4.34it/s, val_loss=0.0545]
# Validating:  83%|████████▎ | 141/169 [00:32<00:06,  4.34it/s, val_loss=0.1036]
# Validating:  84%|████████▍ | 142/169 [00:32<00:06,  4.35it/s, val_loss=0.1036]
# Validating:  84%|████████▍ | 142/169 [00:32<00:06,  4.35it/s, val_loss=0.1936]
# Validating:  85%|████████▍ | 143/169 [00:32<00:05,  4.35it/s, val_loss=0.1936]
# Validating:  85%|████████▍ | 143/169 [00:33<00:05,  4.35it/s, val_loss=0.0187]
# Validating:  85%|████████▌ | 144/169 [00:33<00:05,  4.35it/s, val_loss=0.0187]
# Validating:  85%|████████▌ | 144/169 [00:33<00:05,  4.35it/s, val_loss=0.0326]
# Validating:  86%|████████▌ | 145/169 [00:33<00:05,  4.36it/s, val_loss=0.0326]
# Validating:  86%|████████▌ | 145/169 [00:33<00:05,  4.36it/s, val_loss=0.0111]
# Validating:  86%|████████▋ | 146/169 [00:33<00:05,  4.37it/s, val_loss=0.0111]
# Validating:  86%|████████▋ | 146/169 [00:33<00:05,  4.37it/s, val_loss=0.0412]
# Validating:  87%|████████▋ | 147/169 [00:33<00:05,  4.37it/s, val_loss=0.0412]
# Validating:  87%|████████▋ | 147/169 [00:34<00:05,  4.37it/s, val_loss=0.1584]
# Validating:  88%|████████▊ | 148/169 [00:34<00:04,  4.37it/s, val_loss=0.1584]
# Validating:  88%|████████▊ | 148/169 [00:34<00:04,  4.37it/s, val_loss=0.0129]
# Validating:  88%|████████▊ | 149/169 [00:34<00:04,  4.37it/s, val_loss=0.0129]
# Validating:  88%|████████▊ | 149/169 [00:34<00:04,  4.37it/s, val_loss=0.0357]
# Validating:  89%|████████▉ | 150/169 [00:34<00:04,  4.37it/s, val_loss=0.0357]
# Validating:  89%|████████▉ | 150/169 [00:34<00:04,  4.37it/s, val_loss=0.0392]
# Validating:  89%|████████▉ | 151/169 [00:34<00:04,  4.37it/s, val_loss=0.0392]
# Validating:  89%|████████▉ | 151/169 [00:35<00:04,  4.37it/s, val_loss=0.0346]
# Validating:  90%|████████▉ | 152/169 [00:35<00:03,  4.39it/s, val_loss=0.0346]
# Validating:  90%|████████▉ | 152/169 [00:35<00:03,  4.39it/s, val_loss=0.0866]
# Validating:  91%|█████████ | 153/169 [00:35<00:03,  4.38it/s, val_loss=0.0866]
# Validating:  91%|█████████ | 153/169 [00:35<00:03,  4.38it/s, val_loss=0.3272]
# Validating:  91%|█████████ | 154/169 [00:35<00:03,  4.38it/s, val_loss=0.3272]
# Validating:  91%|█████████ | 154/169 [00:35<00:03,  4.38it/s, val_loss=0.2213]
# Validating:  92%|█████████▏| 155/169 [00:35<00:03,  4.36it/s, val_loss=0.2213]
# Validating:  92%|█████████▏| 155/169 [00:35<00:03,  4.36it/s, val_loss=0.0164]
# Validating:  92%|█████████▏| 156/169 [00:35<00:02,  4.36it/s, val_loss=0.0164]
# Validating:  92%|█████████▏| 156/169 [00:36<00:02,  4.36it/s, val_loss=0.2582]
# Validating:  93%|█████████▎| 157/169 [00:36<00:02,  4.37it/s, val_loss=0.2582]
# Validating:  93%|█████████▎| 157/169 [00:36<00:02,  4.37it/s, val_loss=0.0159]
# Validating:  93%|█████████▎| 158/169 [00:36<00:02,  4.37it/s, val_loss=0.0159]
# Validating:  93%|█████████▎| 158/169 [00:36<00:02,  4.37it/s, val_loss=0.1230]
# Validating:  94%|█████████▍| 159/169 [00:36<00:02,  4.38it/s, val_loss=0.1230]
# Validating:  94%|█████████▍| 159/169 [00:36<00:02,  4.38it/s, val_loss=0.0275]
# Validating:  95%|█████████▍| 160/169 [00:36<00:02,  4.38it/s, val_loss=0.0275]
# Validating:  95%|█████████▍| 160/169 [00:37<00:02,  4.38it/s, val_loss=0.0552]
# Validating:  95%|█████████▌| 161/169 [00:37<00:01,  4.38it/s, val_loss=0.0552]
# Validating:  95%|█████████▌| 161/169 [00:37<00:01,  4.38it/s, val_loss=0.1630]
# Validating:  96%|█████████▌| 162/169 [00:37<00:01,  4.37it/s, val_loss=0.1630]
# Validating:  96%|█████████▌| 162/169 [00:37<00:01,  4.37it/s, val_loss=0.0080]
# Validating:  96%|█████████▋| 163/169 [00:37<00:01,  4.37it/s, val_loss=0.0080]
# Validating:  96%|█████████▋| 163/169 [00:37<00:01,  4.37it/s, val_loss=0.1735]
# Validating:  97%|█████████▋| 164/169 [00:37<00:01,  4.35it/s, val_loss=0.1735]
# Validating:  97%|█████████▋| 164/169 [00:37<00:01,  4.35it/s, val_loss=0.1144]
# Validating:  98%|█████████▊| 165/169 [00:37<00:00,  4.36it/s, val_loss=0.1144]
# Validating:  98%|█████████▊| 165/169 [00:38<00:00,  4.36it/s, val_loss=0.1358]
# Validating:  98%|█████████▊| 166/169 [00:38<00:00,  4.35it/s, val_loss=0.1358]
# Validating:  98%|█████████▊| 166/169 [00:38<00:00,  4.35it/s, val_loss=0.1779]
# Validating:  99%|█████████▉| 167/169 [00:38<00:00,  4.36it/s, val_loss=0.1779]
# Validating:  99%|█████████▉| 167/169 [00:38<00:00,  4.36it/s, val_loss=0.1108]
# Validating:  99%|█████████▉| 168/169 [00:38<00:00,  4.35it/s, val_loss=0.1108]
# Validating:  99%|█████████▉| 168/169 [00:38<00:00,  4.35it/s, val_loss=0.2106]
# Validating: 100%|██████████| 169/169 [00:38<00:00,  4.71it/s, val_loss=0.2106]
# Epoch 1: 100%|██████████| 1350/1350 [06:26<00:00,  3.49it/s, loss=0.1631, lr=0.000200]
#
# Validating:   0%|          | 0/169 [00:00<?, ?it/s]
# Validating:   0%|          | 0/169 [00:00<?, ?it/s, val_loss=0.0420]
# Validating:   1%|          | 1/169 [00:00<01:01,  2.74it/s, val_loss=0.0420]
# Validating:   1%|          | 1/169 [00:00<01:01,  2.74it/s, val_loss=0.1669]
# Validating:   1%|          | 2/169 [00:00<00:47,  3.50it/s, val_loss=0.1669]
# Validating:   1%|          | 2/169 [00:00<00:47,  3.50it/s, val_loss=0.2199]
# Validating:   2%|▏         | 3/169 [00:00<00:43,  3.84it/s, val_loss=0.2199]
# Validating:   2%|▏         | 3/169 [00:01<00:43,  3.84it/s, val_loss=0.2818]
# Validating:   2%|▏         | 4/169 [00:01<00:40,  4.03it/s, val_loss=0.2818]
# Validating:   2%|▏         | 4/169 [00:01<00:40,  4.03it/s, val_loss=0.1057]
# Validating:   3%|▎         | 5/169 [00:01<00:39,  4.13it/s, val_loss=0.1057]
# Validating:   3%|▎         | 5/169 [00:01<00:39,  4.13it/s, val_loss=0.2058]
# Validating:   4%|▎         | 6/169 [00:01<00:38,  4.21it/s, val_loss=0.2058]
# Validating:   4%|▎         | 6/169 [00:01<00:38,  4.21it/s, val_loss=0.3285]
# Validating:   4%|▍         | 7/169 [00:01<00:37,  4.26it/s, val_loss=0.3285]
# Validating:   4%|▍         | 7/169 [00:01<00:37,  4.26it/s, val_loss=0.1708]
# Validating:   5%|▍         | 8/169 [00:01<00:37,  4.28it/s, val_loss=0.1708]
# Validating:   5%|▍         | 8/169 [00:02<00:37,  4.28it/s, val_loss=0.1289]
# Validating:   5%|▌         | 9/169 [00:02<00:37,  4.31it/s, val_loss=0.1289]
# Validating:   5%|▌         | 9/169 [00:02<00:37,  4.31it/s, val_loss=0.1489]
# Validating:   6%|▌         | 10/169 [00:02<00:36,  4.33it/s, val_loss=0.1489]
# Validating:   6%|▌         | 10/169 [00:02<00:36,  4.33it/s, val_loss=0.1848]
# Validating:   7%|▋         | 11/169 [00:02<00:36,  4.34it/s, val_loss=0.1848]
# Validating:   7%|▋         | 11/169 [00:02<00:36,  4.34it/s, val_loss=0.1557]
# Validating:   7%|▋         | 12/169 [00:02<00:36,  4.35it/s, val_loss=0.1557]
# Validating:   7%|▋         | 12/169 [00:03<00:36,  4.35it/s, val_loss=0.0652]
# Validating:   8%|▊         | 13/169 [00:03<00:35,  4.35it/s, val_loss=0.0652]
# Validating:   8%|▊         | 13/169 [00:03<00:35,  4.35it/s, val_loss=0.0556]
# Validating:   8%|▊         | 14/169 [00:03<00:35,  4.35it/s, val_loss=0.0556]
# Validating:   8%|▊         | 14/169 [00:03<00:35,  4.35it/s, val_loss=0.3569]
# Validating:   9%|▉         | 15/169 [00:03<00:35,  4.35it/s, val_loss=0.3569]
# Validating:   9%|▉         | 15/169 [00:03<00:35,  4.35it/s, val_loss=0.0814]
# Validating:   9%|▉         | 16/169 [00:03<00:35,  4.34it/s, val_loss=0.0814]
# Validating:   9%|▉         | 16/169 [00:04<00:35,  4.34it/s, val_loss=0.0907]
# Validating:  10%|█         | 17/169 [00:04<00:34,  4.35it/s, val_loss=0.0907]
# Validating:  10%|█         | 17/169 [00:04<00:34,  4.35it/s, val_loss=0.2085]
# Validating:  11%|█         | 18/169 [00:04<00:34,  4.35it/s, val_loss=0.2085]
# Validating:  11%|█         | 18/169 [00:04<00:34,  4.35it/s, val_loss=0.1248]
# Validating:  11%|█         | 19/169 [00:04<00:34,  4.37it/s, val_loss=0.1248]
# Validating:  11%|█         | 19/169 [00:04<00:34,  4.37it/s, val_loss=0.0756]
# Validating:  12%|█▏        | 20/169 [00:04<00:34,  4.36it/s, val_loss=0.0756]
# Validating:  12%|█▏        | 20/169 [00:04<00:34,  4.36it/s, val_loss=0.1588]
# Validating:  12%|█▏        | 21/169 [00:04<00:33,  4.36it/s, val_loss=0.1588]
# Validating:  12%|█▏        | 21/169 [00:05<00:33,  4.36it/s, val_loss=0.1122]
# Validating:  13%|█▎        | 22/169 [00:05<00:33,  4.35it/s, val_loss=0.1122]
# Validating:  13%|█▎        | 22/169 [00:05<00:33,  4.35it/s, val_loss=0.2153]
# Validating:  14%|█▎        | 23/169 [00:05<00:33,  4.36it/s, val_loss=0.2153]
# Validating:  14%|█▎        | 23/169 [00:05<00:33,  4.36it/s, val_loss=0.0326]
# Validating:  14%|█▍        | 24/169 [00:05<00:33,  4.36it/s, val_loss=0.0326]
# Validating:  14%|█▍        | 24/169 [00:05<00:33,  4.36it/s, val_loss=0.1457]
# Validating:  15%|█▍        | 25/169 [00:05<00:32,  4.37it/s, val_loss=0.1457]
# Validating:  15%|█▍        | 25/169 [00:06<00:32,  4.37it/s, val_loss=0.0804]
# Validating:  15%|█▌        | 26/169 [00:06<00:32,  4.34it/s, val_loss=0.0804]
# Validating:  15%|█▌        | 26/169 [00:06<00:32,  4.34it/s, val_loss=0.1816]
# Validating:  16%|█▌        | 27/169 [00:06<00:32,  4.33it/s, val_loss=0.1816]
# Validating:  16%|█▌        | 27/169 [00:06<00:32,  4.33it/s, val_loss=0.2599]
# Validating:  17%|█▋        | 28/169 [00:06<00:32,  4.34it/s, val_loss=0.2599]
# Validating:  17%|█▋        | 28/169 [00:06<00:32,  4.34it/s, val_loss=0.0748]
# Validating:  17%|█▋        | 29/169 [00:06<00:32,  4.34it/s, val_loss=0.0748]
# Validating:  17%|█▋        | 29/169 [00:07<00:32,  4.34it/s, val_loss=0.1857]
# Validating:  18%|█▊        | 30/169 [00:07<00:31,  4.35it/s, val_loss=0.1857]
# Validating:  18%|█▊        | 30/169 [00:07<00:31,  4.35it/s, val_loss=0.1084]
# Validating:  18%|█▊        | 31/169 [00:07<00:31,  4.35it/s, val_loss=0.1084]
# Validating:  18%|█▊        | 31/169 [00:07<00:31,  4.35it/s, val_loss=0.0880]
# Validating:  19%|█▉        | 32/169 [00:07<00:31,  4.33it/s, val_loss=0.0880]
# Validating:  19%|█▉        | 32/169 [00:07<00:31,  4.33it/s, val_loss=0.0683]
# Validating:  20%|█▉        | 33/169 [00:07<00:31,  4.32it/s, val_loss=0.0683]
# Validating:  20%|█▉        | 33/169 [00:07<00:31,  4.32it/s, val_loss=0.1034]
# Validating:  20%|██        | 34/169 [00:07<00:31,  4.34it/s, val_loss=0.1034]
# Validating:  20%|██        | 34/169 [00:08<00:31,  4.34it/s, val_loss=0.2172]
# Validating:  21%|██        | 35/169 [00:08<00:30,  4.35it/s, val_loss=0.2172]
# Validating:  21%|██        | 35/169 [00:08<00:30,  4.35it/s, val_loss=0.0558]
# Validating:  21%|██▏       | 36/169 [00:08<00:30,  4.35it/s, val_loss=0.0558]
# Validating:  21%|██▏       | 36/169 [00:08<00:30,  4.35it/s, val_loss=0.1726]
# Validating:  22%|██▏       | 37/169 [00:08<00:30,  4.35it/s, val_loss=0.1726]
# Validating:  22%|██▏       | 37/169 [00:08<00:30,  4.35it/s, val_loss=0.1003]
# Validating:  22%|██▏       | 38/169 [00:08<00:30,  4.35it/s, val_loss=0.1003]
# Validating:  22%|██▏       | 38/169 [00:09<00:30,  4.35it/s, val_loss=0.2689]
# Validating:  23%|██▎       | 39/169 [00:09<00:29,  4.36it/s, val_loss=0.2689]
# Validating:  23%|██▎       | 39/169 [00:09<00:29,  4.36it/s, val_loss=0.1178]
# Validating:  24%|██▎       | 40/169 [00:09<00:29,  4.35it/s, val_loss=0.1178]
# Validating:  24%|██▎       | 40/169 [00:09<00:29,  4.35it/s, val_loss=0.1065]
# Validating:  24%|██▍       | 41/169 [00:09<00:29,  4.36it/s, val_loss=0.1065]
# Validating:  24%|██▍       | 41/169 [00:09<00:29,  4.36it/s, val_loss=0.1691]
# Validating:  25%|██▍       | 42/169 [00:09<00:29,  4.35it/s, val_loss=0.1691]
# Validating:  25%|██▍       | 42/169 [00:10<00:29,  4.35it/s, val_loss=0.2282]
# Validating:  25%|██▌       | 43/169 [00:10<00:28,  4.36it/s, val_loss=0.2282]
# Validating:  25%|██▌       | 43/169 [00:10<00:28,  4.36it/s, val_loss=0.4024]
# Validating:  26%|██▌       | 44/169 [00:10<00:28,  4.35it/s, val_loss=0.4024]
# Validating:  26%|██▌       | 44/169 [00:10<00:28,  4.35it/s, val_loss=0.2227]
# Validating:  27%|██▋       | 45/169 [00:10<00:28,  4.35it/s, val_loss=0.2227]
# Validating:  27%|██▋       | 45/169 [00:10<00:28,  4.35it/s, val_loss=0.0636]
# Validating:  27%|██▋       | 46/169 [00:10<00:28,  4.36it/s, val_loss=0.0636]
# Validating:  27%|██▋       | 46/169 [00:10<00:28,  4.36it/s, val_loss=0.2822]
# Validating:  28%|██▊       | 47/169 [00:10<00:28,  4.34it/s, val_loss=0.2822]
# Validating:  28%|██▊       | 47/169 [00:11<00:28,  4.34it/s, val_loss=0.1177]
# Validating:  28%|██▊       | 48/169 [00:11<00:27,  4.33it/s, val_loss=0.1177]
# Validating:  28%|██▊       | 48/169 [00:11<00:27,  4.33it/s, val_loss=0.0768]
# Validating:  29%|██▉       | 49/169 [00:11<00:27,  4.35it/s, val_loss=0.0768]
# Validating:  29%|██▉       | 49/169 [00:11<00:27,  4.35it/s, val_loss=0.1721]
# Validating:  30%|██▉       | 50/169 [00:11<00:27,  4.35it/s, val_loss=0.1721]
# Validating:  30%|██▉       | 50/169 [00:11<00:27,  4.35it/s, val_loss=0.0329]
# Validating:  30%|███       | 51/169 [00:11<00:27,  4.36it/s, val_loss=0.0329]
# Validating:  30%|███       | 51/169 [00:12<00:27,  4.36it/s, val_loss=0.0631]
# Validating:  31%|███       | 52/169 [00:12<00:26,  4.37it/s, val_loss=0.0631]
# Validating:  31%|███       | 52/169 [00:12<00:26,  4.37it/s, val_loss=0.1801]
# Validating:  31%|███▏      | 53/169 [00:12<00:26,  4.37it/s, val_loss=0.1801]
# Validating:  31%|███▏      | 53/169 [00:12<00:26,  4.37it/s, val_loss=0.1320]
# Validating:  32%|███▏      | 54/169 [00:12<00:26,  4.36it/s, val_loss=0.1320]
# Validating:  32%|███▏      | 54/169 [00:12<00:26,  4.36it/s, val_loss=0.0639]
# Validating:  33%|███▎      | 55/169 [00:12<00:26,  4.37it/s, val_loss=0.0639]
# Validating:  33%|███▎      | 55/169 [00:12<00:26,  4.37it/s, val_loss=0.1336]
# Validating:  33%|███▎      | 56/169 [00:12<00:25,  4.37it/s, val_loss=0.1336]
# Validating:  33%|███▎      | 56/169 [00:13<00:25,  4.37it/s, val_loss=0.2047]
# Validating:  34%|███▎      | 57/169 [00:13<00:25,  4.38it/s, val_loss=0.2047]
# Validating:  34%|███▎      | 57/169 [00:13<00:25,  4.38it/s, val_loss=0.1043]
# Validating:  34%|███▍      | 58/169 [00:13<00:25,  4.39it/s, val_loss=0.1043]
# Validating:  34%|███▍      | 58/169 [00:13<00:25,  4.39it/s, val_loss=0.2135]
# Validating:  35%|███▍      | 59/169 [00:13<00:25,  4.38it/s, val_loss=0.2135]
# Validating:  35%|███▍      | 59/169 [00:13<00:25,  4.38it/s, val_loss=0.1513]
# Validating:  36%|███▌      | 60/169 [00:13<00:24,  4.38it/s, val_loss=0.1513]
# Validating:  36%|███▌      | 60/169 [00:14<00:24,  4.38it/s, val_loss=0.1500]
# Validating:  36%|███▌      | 61/169 [00:14<00:24,  4.37it/s, val_loss=0.1500]
# Validating:  36%|███▌      | 61/169 [00:14<00:24,  4.37it/s, val_loss=0.3369]
# Validating:  37%|███▋      | 62/169 [00:14<00:24,  4.37it/s, val_loss=0.3369]
# Validating:  37%|███▋      | 62/169 [00:14<00:24,  4.37it/s, val_loss=0.0629]
# Validating:  37%|███▋      | 63/169 [00:14<00:24,  4.36it/s, val_loss=0.0629]
# Validating:  37%|███▋      | 63/169 [00:14<00:24,  4.36it/s, val_loss=0.0763]
# Validating:  38%|███▊      | 64/169 [00:14<00:24,  4.35it/s, val_loss=0.0763]
# Validating:  38%|███▊      | 64/169 [00:15<00:24,  4.35it/s, val_loss=0.2016]
# Validating:  38%|███▊      | 65/169 [00:15<00:23,  4.36it/s, val_loss=0.2016]
# Validating:  38%|███▊      | 65/169 [00:15<00:23,  4.36it/s, val_loss=0.2872]
# Validating:  39%|███▉      | 66/169 [00:15<00:23,  4.34it/s, val_loss=0.2872]
# Validating:  39%|███▉      | 66/169 [00:15<00:23,  4.34it/s, val_loss=0.0259]
# Validating:  40%|███▉      | 67/169 [00:15<00:23,  4.34it/s, val_loss=0.0259]
# Validating:  40%|███▉      | 67/169 [00:15<00:23,  4.34it/s, val_loss=0.0577]
# Validating:  40%|████      | 68/169 [00:15<00:23,  4.35it/s, val_loss=0.0577]
# Validating:  40%|████      | 68/169 [00:15<00:23,  4.35it/s, val_loss=0.0378]
# Validating:  41%|████      | 69/169 [00:15<00:23,  4.34it/s, val_loss=0.0378]
# Validating:  41%|████      | 69/169 [00:16<00:23,  4.34it/s, val_loss=0.0727]
# Validating:  41%|████▏     | 70/169 [00:16<00:22,  4.33it/s, val_loss=0.0727]
# Validating:  41%|████▏     | 70/169 [00:16<00:22,  4.33it/s, val_loss=0.0453]
# Validating:  42%|████▏     | 71/169 [00:16<00:22,  4.35it/s, val_loss=0.0453]
# Validating:  42%|████▏     | 71/169 [00:16<00:22,  4.35it/s, val_loss=0.1582]
# Validating:  43%|████▎     | 72/169 [00:16<00:22,  4.34it/s, val_loss=0.1582]
# Validating:  43%|████▎     | 72/169 [00:16<00:22,  4.34it/s, val_loss=0.2272]
# Validating:  43%|████▎     | 73/169 [00:16<00:22,  4.34it/s, val_loss=0.2272]
# Validating:  43%|████▎     | 73/169 [00:17<00:22,  4.34it/s, val_loss=0.0378]
# Validating:  44%|████▍     | 74/169 [00:17<00:21,  4.33it/s, val_loss=0.0378]
# Validating:  44%|████▍     | 74/169 [00:17<00:21,  4.33it/s, val_loss=0.3460]
# Validating:  44%|████▍     | 75/169 [00:17<00:21,  4.35it/s, val_loss=0.3460]
# Validating:  44%|████▍     | 75/169 [00:17<00:21,  4.35it/s, val_loss=0.0660]
# Validating:  45%|████▍     | 76/169 [00:17<00:21,  4.35it/s, val_loss=0.0660]
# Validating:  45%|████▍     | 76/169 [00:17<00:21,  4.35it/s, val_loss=0.2883]
# Validating:  46%|████▌     | 77/169 [00:17<00:21,  4.35it/s, val_loss=0.2883]
# Validating:  46%|████▌     | 77/169 [00:18<00:21,  4.35it/s, val_loss=0.0792]
# Validating:  46%|████▌     | 78/169 [00:18<00:20,  4.35it/s, val_loss=0.0792]
# Validating:  46%|████▌     | 78/169 [00:18<00:20,  4.35it/s, val_loss=0.0946]
# Validating:  47%|████▋     | 79/169 [00:18<00:20,  4.35it/s, val_loss=0.0946]
# Validating:  47%|████▋     | 79/169 [00:18<00:20,  4.35it/s, val_loss=0.2665]
# Validating:  47%|████▋     | 80/169 [00:18<00:20,  4.34it/s, val_loss=0.2665]
# Validating:  47%|████▋     | 80/169 [00:18<00:20,  4.34it/s, val_loss=0.1200]
# Validating:  48%|████▊     | 81/169 [00:18<00:20,  4.34it/s, val_loss=0.1200]
# Validating:  48%|████▊     | 81/169 [00:18<00:20,  4.34it/s, val_loss=0.2288]
# Validating:  49%|████▊     | 82/169 [00:18<00:20,  4.34it/s, val_loss=0.2288]
# Validating:  49%|████▊     | 82/169 [00:19<00:20,  4.34it/s, val_loss=0.0811]
# Validating:  49%|████▉     | 83/169 [00:19<00:19,  4.34it/s, val_loss=0.0811]
# Validating:  49%|████▉     | 83/169 [00:19<00:19,  4.34it/s, val_loss=0.0698]
# Validating:  50%|████▉     | 84/169 [00:19<00:19,  4.35it/s, val_loss=0.0698]
# Validating:  50%|████▉     | 84/169 [00:19<00:19,  4.35it/s, val_loss=0.1169]
# Validating:  50%|█████     | 85/169 [00:19<00:19,  4.35it/s, val_loss=0.1169]
# Validating:  50%|█████     | 85/169 [00:19<00:19,  4.35it/s, val_loss=0.0779]
# Validating:  51%|█████     | 86/169 [00:19<00:19,  4.34it/s, val_loss=0.0779]
# Validating:  51%|█████     | 86/169 [00:20<00:19,  4.34it/s, val_loss=0.0274]
# Validating:  51%|█████▏    | 87/169 [00:20<00:18,  4.35it/s, val_loss=0.0274]
# Validating:  51%|█████▏    | 87/169 [00:20<00:18,  4.35it/s, val_loss=0.0831]
# Validating:  52%|█████▏    | 88/169 [00:20<00:18,  4.34it/s, val_loss=0.0831]
# Validating:  52%|█████▏    | 88/169 [00:20<00:18,  4.34it/s, val_loss=0.1199]
# Validating:  53%|█████▎    | 89/169 [00:20<00:18,  4.35it/s, val_loss=0.1199]
# Validating:  53%|█████▎    | 89/169 [00:20<00:18,  4.35it/s, val_loss=0.2515]
# Validating:  53%|█████▎    | 90/169 [00:20<00:18,  4.37it/s, val_loss=0.2515]
# Validating:  53%|█████▎    | 90/169 [00:21<00:18,  4.37it/s, val_loss=0.1291]
# Validating:  54%|█████▍    | 91/169 [00:21<00:17,  4.37it/s, val_loss=0.1291]
# Validating:  54%|█████▍    | 91/169 [00:21<00:17,  4.37it/s, val_loss=0.1534]
# Validating:  54%|█████▍    | 92/169 [00:21<00:17,  4.37it/s, val_loss=0.1534]
# Validating:  54%|█████▍    | 92/169 [00:21<00:17,  4.37it/s, val_loss=0.0496]
# Validating:  55%|█████▌    | 93/169 [00:21<00:17,  4.35it/s, val_loss=0.0496]
# Validating:  55%|█████▌    | 93/169 [00:21<00:17,  4.35it/s, val_loss=0.0293]
# Validating:  56%|█████▌    | 94/169 [00:21<00:17,  4.35it/s, val_loss=0.0293]
# Validating:  56%|█████▌    | 94/169 [00:21<00:17,  4.35it/s, val_loss=0.2272]
# Validating:  56%|█████▌    | 95/169 [00:21<00:17,  4.35it/s, val_loss=0.2272]
# Validating:  56%|█████▌    | 95/169 [00:22<00:17,  4.35it/s, val_loss=0.2364]
# Validating:  57%|█████▋    | 96/169 [00:22<00:16,  4.35it/s, val_loss=0.2364]
# Validating:  57%|█████▋    | 96/169 [00:22<00:16,  4.35it/s, val_loss=0.2455]
# Validating:  57%|█████▋    | 97/169 [00:22<00:16,  4.35it/s, val_loss=0.2455]
# Validating:  57%|█████▋    | 97/169 [00:22<00:16,  4.35it/s, val_loss=0.0903]
# Validating:  58%|█████▊    | 98/169 [00:22<00:16,  4.35it/s, val_loss=0.0903]
# Validating:  58%|█████▊    | 98/169 [00:22<00:16,  4.35it/s, val_loss=0.1157]
# Validating:  59%|█████▊    | 99/169 [00:22<00:16,  4.33it/s, val_loss=0.1157]
# Validating:  59%|█████▊    | 99/169 [00:23<00:16,  4.33it/s, val_loss=0.2113]
# Validating:  59%|█████▉    | 100/169 [00:23<00:15,  4.33it/s, val_loss=0.2113]
# Validating:  59%|█████▉    | 100/169 [00:23<00:15,  4.33it/s, val_loss=0.0622]
# Validating:  60%|█████▉    | 101/169 [00:23<00:15,  4.34it/s, val_loss=0.0622]
# Validating:  60%|█████▉    | 101/169 [00:23<00:15,  4.34it/s, val_loss=0.3724]
# Validating:  60%|██████    | 102/169 [00:23<00:15,  4.35it/s, val_loss=0.3724]
# Validating:  60%|██████    | 102/169 [00:23<00:15,  4.35it/s, val_loss=0.1436]
# Validating:  61%|██████    | 103/169 [00:23<00:15,  4.35it/s, val_loss=0.1436]
# Validating:  61%|██████    | 103/169 [00:24<00:15,  4.35it/s, val_loss=0.1912]
# Validating:  62%|██████▏   | 104/169 [00:24<00:14,  4.36it/s, val_loss=0.1912]
# Validating:  62%|██████▏   | 104/169 [00:24<00:14,  4.36it/s, val_loss=0.1103]
# Validating:  62%|██████▏   | 105/169 [00:24<00:14,  4.36it/s, val_loss=0.1103]
# Validating:  62%|██████▏   | 105/169 [00:24<00:14,  4.36it/s, val_loss=0.1353]
# Validating:  63%|██████▎   | 106/169 [00:24<00:14,  4.36it/s, val_loss=0.1353]
# Validating:  63%|██████▎   | 106/169 [00:24<00:14,  4.36it/s, val_loss=0.1673]
# Validating:  63%|██████▎   | 107/169 [00:24<00:14,  4.35it/s, val_loss=0.1673]
# Validating:  63%|██████▎   | 107/169 [00:24<00:14,  4.35it/s, val_loss=0.0775]
# Validating:  64%|██████▍   | 108/169 [00:24<00:13,  4.36it/s, val_loss=0.0775]
# Validating:  64%|██████▍   | 108/169 [00:25<00:13,  4.36it/s, val_loss=0.0197]
# Validating:  64%|██████▍   | 109/169 [00:25<00:13,  4.35it/s, val_loss=0.0197]
# Validating:  64%|██████▍   | 109/169 [00:25<00:13,  4.35it/s, val_loss=0.1102]
# Validating:  65%|██████▌   | 110/169 [00:25<00:13,  4.36it/s, val_loss=0.1102]
# Validating:  65%|██████▌   | 110/169 [00:25<00:13,  4.36it/s, val_loss=0.1267]
# Validating:  66%|██████▌   | 111/169 [00:25<00:13,  4.36it/s, val_loss=0.1267]
# Validating:  66%|██████▌   | 111/169 [00:25<00:13,  4.36it/s, val_loss=0.2464]
# Validating:  66%|██████▋   | 112/169 [00:25<00:13,  4.38it/s, val_loss=0.2464]
# Validating:  66%|██████▋   | 112/169 [00:26<00:13,  4.38it/s, val_loss=0.1301]
# Validating:  67%|██████▋   | 113/169 [00:26<00:12,  4.38it/s, val_loss=0.1301]
# Validating:  67%|██████▋   | 113/169 [00:26<00:12,  4.38it/s, val_loss=0.1714]
# Validating:  67%|██████▋   | 114/169 [00:26<00:12,  4.37it/s, val_loss=0.1714]
# Validating:  67%|██████▋   | 114/169 [00:26<00:12,  4.37it/s, val_loss=0.0388]
# Validating:  68%|██████▊   | 115/169 [00:26<00:12,  4.36it/s, val_loss=0.0388]
# Validating:  68%|██████▊   | 115/169 [00:26<00:12,  4.36it/s, val_loss=0.0843]
# Validating:  69%|██████▊   | 116/169 [00:26<00:12,  4.36it/s, val_loss=0.0843]
# Validating:  69%|██████▊   | 116/169 [00:27<00:12,  4.36it/s, val_loss=0.1541]
# Validating:  69%|██████▉   | 117/169 [00:27<00:11,  4.35it/s, val_loss=0.1541]
# Validating:  69%|██████▉   | 117/169 [00:27<00:11,  4.35it/s, val_loss=0.0311]
# Validating:  70%|██████▉   | 118/169 [00:27<00:11,  4.35it/s, val_loss=0.0311]
# Validating:  70%|██████▉   | 118/169 [00:27<00:11,  4.35it/s, val_loss=0.3193]
# Validating:  70%|███████   | 119/169 [00:27<00:11,  4.33it/s, val_loss=0.3193]
# Validating:  70%|███████   | 119/169 [00:27<00:11,  4.33it/s, val_loss=0.2376]
# Validating:  71%|███████   | 120/169 [00:27<00:11,  4.34it/s, val_loss=0.2376]
# Validating:  71%|███████   | 120/169 [00:27<00:11,  4.34it/s, val_loss=0.0332]
# Validating:  72%|███████▏  | 121/169 [00:27<00:11,  4.34it/s, val_loss=0.0332]
# Validating:  72%|███████▏  | 121/169 [00:28<00:11,  4.34it/s, val_loss=0.2528]
# Validating:  72%|███████▏  | 122/169 [00:28<00:10,  4.34it/s, val_loss=0.2528]
# Validating:  72%|███████▏  | 122/169 [00:28<00:10,  4.34it/s, val_loss=0.0210]
# Validating:  73%|███████▎  | 123/169 [00:28<00:10,  4.33it/s, val_loss=0.0210]
# Validating:  73%|███████▎  | 123/169 [00:28<00:10,  4.33it/s, val_loss=0.1661]
# Validating:  73%|███████▎  | 124/169 [00:28<00:10,  4.34it/s, val_loss=0.1661]
# Validating:  73%|███████▎  | 124/169 [00:28<00:10,  4.34it/s, val_loss=0.1306]
# Validating:  74%|███████▍  | 125/169 [00:28<00:10,  4.34it/s, val_loss=0.1306]
# Validating:  74%|███████▍  | 125/169 [00:29<00:10,  4.34it/s, val_loss=0.0409]
# Validating:  75%|███████▍  | 126/169 [00:29<00:09,  4.34it/s, val_loss=0.0409]
# Validating:  75%|███████▍  | 126/169 [00:29<00:09,  4.34it/s, val_loss=0.2652]
# Validating:  75%|███████▌  | 127/169 [00:29<00:09,  4.34it/s, val_loss=0.2652]
# Validating:  75%|███████▌  | 127/169 [00:29<00:09,  4.34it/s, val_loss=0.2671]
# Validating:  76%|███████▌  | 128/169 [00:29<00:09,  4.35it/s, val_loss=0.2671]
# Validating:  76%|███████▌  | 128/169 [00:29<00:09,  4.35it/s, val_loss=0.1166]
# Validating:  76%|███████▋  | 129/169 [00:29<00:09,  4.34it/s, val_loss=0.1166]
# Validating:  76%|███████▋  | 129/169 [00:30<00:09,  4.34it/s, val_loss=0.0714]
# Validating:  77%|███████▋  | 130/169 [00:30<00:09,  4.33it/s, val_loss=0.0714]
# Validating:  77%|███████▋  | 130/169 [00:30<00:09,  4.33it/s, val_loss=0.0411]
# Validating:  78%|███████▊  | 131/169 [00:30<00:08,  4.34it/s, val_loss=0.0411]
# Validating:  78%|███████▊  | 131/169 [00:30<00:08,  4.34it/s, val_loss=0.0618]
# Validating:  78%|███████▊  | 132/169 [00:30<00:08,  4.35it/s, val_loss=0.0618]
# Validating:  78%|███████▊  | 132/169 [00:30<00:08,  4.35it/s, val_loss=0.0922]
# ...
# Validating:  14%|█▎        | 23/169 [00:05<00:33,  4.36it/s, val_loss=0.1560]
# Validating:  14%|█▎        | 23/169 [00:05<00:33,  4.36it/s, val_loss=0.2012]
# Validating:  14%|█▍        | 24/169 [00:05<00:33,  4.35it/s, val_loss=0.2012]
# Validating:  14%|█▍        | 24/169 [00:05<00:33,  4.35it/s, val_loss=0.2379]
# Validating:  15%|█▍        | 25/169 [00:05<00:33,  4.35it/s, val_loss=0.2379]
# Validating:  15%|█▍        | 25/169 [00:06<00:33,  4.35it/s, val_loss=0.1354]
# Validating:  15%|█▌        | 26/169 [00:06<00:32,  4.36it/s, val_loss=0.1354]
# Validating:  15%|█▌        | 26/169 [00:06<00:32,  4.36it/s, val_loss=0.1272]
# Validating:  16%|█▌        | 27/169 [00:06<00:32,  4.35it/s, val_loss=0.1272]
# Validating:  16%|█▌        | 27/169 [00:06<00:32,  4.35it/s, val_loss=0.1311]
# Validating:  17%|█▋        | 28/169 [00:06<00:32,  4.35it/s, val_loss=0.1311]
# Validating:  17%|█▋        | 28/169 [00:06<00:32,  4.35it/s, val_loss=0.1362]
# Validating:  17%|█▋        | 29/169 [00:06<00:32,  4.36it/s, val_loss=0.1362]
# Validating:  17%|█▋        | 29/169 [00:07<00:32,  4.36it/s, val_loss=0.1536]
# Validating:  18%|█▊        | 30/169 [00:07<00:31,  4.35it/s, val_loss=0.1536]
# Validating:  18%|█▊        | 30/169 [00:07<00:31,  4.35it/s, val_loss=0.0723]
# Validating:  18%|█▊        | 31/169 [00:07<00:31,  4.35it/s, val_loss=0.0723]
# Validating:  18%|█▊        | 31/169 [00:07<00:31,  4.35it/s, val_loss=0.0778]
# Validating:  19%|█▉        | 32/169 [00:07<00:31,  4.35it/s, val_loss=0.0778]
# Validating:  19%|█▉        | 32/169 [00:07<00:31,  4.35it/s, val_loss=0.1312]
# Validating:  20%|█▉        | 33/169 [00:07<00:31,  4.34it/s, val_loss=0.1312]
# Validating:  20%|█▉        | 33/169 [00:07<00:31,  4.34it/s, val_loss=0.2847]
# Validating:  20%|██        | 34/169 [00:07<00:31,  4.35it/s, val_loss=0.2847]
# Validating:  20%|██        | 34/169 [00:08<00:31,  4.35it/s, val_loss=0.2176]
# Validating:  21%|██        | 35/169 [00:08<00:30,  4.34it/s, val_loss=0.2176]
# Validating:  21%|██        | 35/169 [00:08<00:30,  4.34it/s, val_loss=0.1684]
# Validating:  21%|██▏       | 36/169 [00:08<00:30,  4.35it/s, val_loss=0.1684]
# Validating:  21%|██▏       | 36/169 [00:08<00:30,  4.35it/s, val_loss=0.0906]
# Validating:  22%|██▏       | 37/169 [00:08<00:30,  4.35it/s, val_loss=0.0906]
# Epoch 71:  91%|█████████ | 1228/1350 [05:54<00:31,  3.88it/s, loss=0.2198, lr=0.000006]
# Validating:  88%|████████▊ | 149/169 [00:34<00:04,  4.36it/s, val_loss=0.0085]
# Validating:  89%|████████▉ | 150/169 [00:34<00:04,  4.36it/s, val_loss=0.0085]
# Validating:  89%|████████▉ | 150/169 [00:34<00:04,  4.36it/s, val_loss=0.0722]
# Validating:  89%|████████▉ | 151/169 [00:34<00:04,  4.37it/s, val_loss=0.0722]
# Validating:  89%|████████▉ | 151/169 [00:35<00:04,  4.37it/s, val_loss=0.0920]
# Validating:  90%|████████▉ | 152/169 [00:35<00:03,  4.35it/s, val_loss=0.0920]
# Validating:  90%|████████▉ | 152/169 [00:35<00:03,  4.35it/s, val_loss=0.0509]
# Validating:  91%|█████████ | 153/169 [00:35<00:03,  4.37it/s, val_loss=0.0509]
# Validating:  91%|█████████ | 153/169 [00:35<00:03,  4.37it/s, val_loss=0.0579]
# Validating:  91%|█████████ | 154/169 [00:35<00:03,  4.37it/s, val_loss=0.0579]
# Validating:  91%|█████████ | 154/169 [00:35<00:03,  4.37it/s, val_loss=0.0361]
# Validating:  92%|█████████▏| 155/169 [00:35<00:03,  4.35it/s, val_loss=0.0361]
# Validating:  92%|█████████▏| 155/169 [00:35<00:03,  4.35it/s, val_loss=0.0761]
# Validating:  92%|█████████▏| 156/169 [00:35<00:02,  4.36it/s, val_loss=0.0761]
# Validating:  92%|█████████▏| 156/169 [00:36<00:02,  4.36it/s, val_loss=0.1163]
# Validating:  93%|█████████▎| 157/169 [00:36<00:02,  4.36it/s, val_loss=0.1163]
# Validating:  93%|█████████▎| 157/169 [00:36<00:02,  4.36it/s, val_loss=0.0713]
# Validating:  93%|█████████▎| 158/169 [00:36<00:02,  4.36it/s, val_loss=0.0713]
# Validating:  93%|█████████▎| 158/169 [00:36<00:02,  4.36it/s, val_loss=0.1362]
# Validating:  94%|█████████▍| 159/169 [00:36<00:02,  4.35it/s, val_loss=0.1362]
# Validating:  94%|█████████▍| 159/169 [00:36<00:02,  4.35it/s, val_loss=0.1254]
# Validating:  95%|█████████▍| 160/169 [00:36<00:02,  4.35it/s, val_loss=0.1254]
# Validating:  95%|█████████▍| 160/169 [00:37<00:02,  4.35it/s, val_loss=0.2146]
# Validating:  95%|█████████▌| 161/169 [00:37<00:01,  4.35it/s, val_loss=0.2146]
# Validating:  95%|█████████▌| 161/169 [00:37<00:01,  4.35it/s, val_loss=0.0845]
# Validating:  96%|█████████▌| 162/169 [00:37<00:01,  4.35it/s, val_loss=0.0845]
# Validating:  96%|█████████▌| 162/169 [00:37<00:01,  4.35it/s, val_loss=0.0188]
# Validating:  96%|█████████▋| 163/169 [00:37<00:01,  4.36it/s, val_loss=0.0188]
# Validating:  96%|█████████▋| 163/169 [00:37<00:01,  4.36it/s, val_loss=0.1035]
# Validating:  97%|█████████▋| 164/169 [00:37<00:01,  4.36it/s, val_loss=0.1035]
# Validating:  97%|█████████▋| 164/169 [00:38<00:01,  4.36it/s, val_loss=0.1099]
# Validating:  98%|█████████▊| 165/169 [00:38<00:00,  4.37it/s, val_loss=0.1099]
# Validating:  98%|█████████▊| 165/169 [00:38<00:00,  4.37it/s, val_loss=0.0947]
# Validating:  98%|█████████▊| 166/169 [00:38<00:00,  4.36it/s, val_loss=0.0947]
# Validating:  98%|█████████▊| 166/169 [00:38<00:00,  4.36it/s, val_loss=0.0820]
# Validating:  99%|█████████▉| 167/169 [00:38<00:00,  4.36it/s, val_loss=0.0820]
# Validating:  99%|█████████▉| 167/169 [00:38<00:00,  4.36it/s, val_loss=0.0075]
# Validating:  99%|█████████▉| 168/169 [00:38<00:00,  4.36it/s, val_loss=0.0075]
# Validating:  99%|█████████▉| 168/169 [00:38<00:00,  4.36it/s, val_loss=0.0659]
# Validating: 100%|██████████| 169/169 [00:38<00:00,  4.73it/s, val_loss=0.0659]
# Epoch 78:  89%|████████▉ | 1200/1350 [05:47<00:38,  3.92it/s, loss=0.1377, lr=0.000006]
# Validating:  86%|████████▌ | 145/169 [00:33<00:05,  4.37it/s, val_loss=0.0469]
# Validating:  86%|████████▋ | 146/169 [00:33<00:05,  4.36it/s, val_loss=0.0469]
# Validating:  86%|████████▋ | 146/169 [00:33<00:05,  4.36it/s, val_loss=0.0108]
# Validating:  87%|████████▋ | 147/169 [00:33<00:05,  4.38it/s, val_loss=0.0108]
# Validating:  87%|████████▋ | 147/169 [00:34<00:05,  4.38it/s, val_loss=0.0535]
# Validating:  88%|████████▊ | 148/169 [00:34<00:04,  4.37it/s, val_loss=0.0535]
# Validating:  88%|████████▊ | 148/169 [00:34<00:04,  4.37it/s, val_loss=0.0686]
# Validating:  88%|████████▊ | 149/169 [00:34<00:04,  4.36it/s, val_loss=0.0686]
# Validating:  88%|████████▊ | 149/169 [00:34<00:04,  4.36it/s, val_loss=0.0632]
# Validating:  89%|████████▉ | 150/169 [00:34<00:04,  4.38it/s, val_loss=0.0632]
# Validating:  89%|████████▉ | 150/169 [00:34<00:04,  4.38it/s, val_loss=0.0831]
# Validating:  89%|████████▉ | 151/169 [00:34<00:04,  4.37it/s, val_loss=0.0831]
# Validating:  89%|████████▉ | 151/169 [00:35<00:04,  4.37it/s, val_loss=0.1224]
# Validating:  90%|████████▉ | 152/169 [00:35<00:03,  4.37it/s, val_loss=0.1224]
# Validating:  90%|████████▉ | 152/169 [00:35<00:03,  4.37it/s, val_loss=0.1177]
# Validating:  91%|█████████ | 153/169 [00:35<00:03,  4.36it/s, val_loss=0.1177]
# Validating:  91%|█████████ | 153/169 [00:35<00:03,  4.36it/s, val_loss=0.1826]
# Validating:  91%|█████████ | 154/169 [00:35<00:03,  4.36it/s, val_loss=0.1826]
# Validating:  91%|█████████ | 154/169 [00:35<00:03,  4.36it/s, val_loss=0.0894]
# Validating:  92%|█████████▏| 155/169 [00:35<00:03,  4.36it/s, val_loss=0.0894]
# Validating:  92%|█████████▏| 155/169 [00:35<00:03,  4.36it/s, val_loss=0.0366]
# Validating:  92%|█████████▏| 156/169 [00:35<00:02,  4.38it/s, val_loss=0.0366]
# Validating:  92%|█████████▏| 156/169 [00:36<00:02,  4.38it/s, val_loss=0.0463]
# Validating:  93%|█████████▎| 157/169 [00:36<00:02,  4.36it/s, val_loss=0.0463]
# Validating:  93%|█████████▎| 157/169 [00:36<00:02,  4.36it/s, val_loss=0.0273]
# Validating:  93%|█████████▎| 158/169 [00:36<00:02,  4.37it/s, val_loss=0.0273]
# Validating:  93%|█████████▎| 158/169 [00:36<00:02,  4.37it/s, val_loss=0.1401]
# Validating:  94%|█████████▍| 159/169 [00:36<00:02,  4.36it/s, val_loss=0.1401]
# Validating:  94%|█████████▍| 159/169 [00:36<00:02,  4.36it/s, val_loss=0.0429]
# Validating:  95%|█████████▍| 160/169 [00:36<00:02,  4.36it/s, val_loss=0.0429]
# Validating:  95%|█████████▍| 160/169 [00:37<00:02,  4.36it/s, val_loss=0.0092]
# Validating:  95%|█████████▌| 161/169 [00:37<00:01,  4.37it/s, val_loss=0.0092]
# Validating:  95%|█████████▌| 161/169 [00:37<00:01,  4.37it/s, val_loss=0.0728]
# Validating:  96%|█████████▌| 162/169 [00:37<00:01,  4.37it/s, val_loss=0.0728]
# Validating:  96%|█████████▌| 162/169 [00:37<00:01,  4.37it/s, val_loss=0.0289]
# Validating:  96%|█████████▋| 163/169 [00:37<00:01,  4.38it/s, val_loss=0.0289]
# Validating:  96%|█████████▋| 163/169 [00:37<00:01,  4.38it/s, val_loss=0.0233]
# Validating:  97%|█████████▋| 164/169 [00:37<00:01,  4.38it/s, val_loss=0.0233]
# Validating:  97%|█████████▋| 164/169 [00:38<00:01,  4.38it/s, val_loss=0.0286]
# Validating:  98%|█████████▊| 165/169 [00:38<00:00,  4.37it/s, val_loss=0.0286]
# Validating:  98%|█████████▊| 165/169 [00:38<00:00,  4.37it/s, val_loss=0.0753]
# Validating:  98%|█████████▊| 166/169 [00:38<00:00,  4.38it/s, val_loss=0.0753]
# Validating:  98%|█████████▊| 166/169 [00:38<00:00,  4.38it/s, val_loss=0.2289]
# Validating:  99%|█████████▉| 167/169 [00:38<00:00,  4.37it/s, val_loss=0.2289]
# Validating:  99%|█████████▉| 167/169 [00:38<00:00,  4.37it/s, val_loss=0.1786]
# Validating:  99%|█████████▉| 168/169 [00:38<00:00,  4.38it/s, val_loss=0.1786]
# Validating:  99%|█████████▉| 168/169 [00:38<00:00,  4.38it/s, val_loss=0.0664]
# Validating: 100%|██████████| 169/169 [00:38<00:00,  4.75it/s, val_loss=0.0664]
# Epoch 84: 100%|██████████| 1350/1350 [06:26<00:00,  3.50it/s, loss=0.1096, lr=0.000003]
#
# Validating:   0%|          | 0/169 [00:00<?, ?it/s]
# Validating:   0%|          | 0/169 [00:00<?, ?it/s, val_loss=0.1281]
# Validating:   1%|          | 1/169 [00:00<01:02,  2.68it/s, val_loss=0.1281]
# Validating:   1%|          | 1/169 [00:00<01:02,  2.68it/s, val_loss=0.0549]
# Validating:   1%|          | 2/169 [00:00<00:48,  3.46it/s, val_loss=0.0549]
# Validating:   1%|          | 2/169 [00:00<00:48,  3.46it/s, val_loss=0.1504]
# Validating:   2%|▏         | 3/169 [00:00<00:43,  3.83it/s, val_loss=0.1504]
# Validating:   2%|▏         | 3/169 [00:01<00:43,  3.83it/s, val_loss=0.1359]
# Validating:   2%|▏         | 4/169 [00:01<00:41,  4.02it/s, val_loss=0.1359]
# Validating:   2%|▏         | 4/169 [00:01<00:41,  4.02it/s, val_loss=0.1237]
# Validating:   3%|▎         | 5/169 [00:01<00:39,  4.15it/s, val_loss=0.1237]
# Validating:   3%|▎         | 5/169 [00:01<00:39,  4.15it/s, val_loss=0.1132]
# Validating:   4%|▎         | 6/169 [00:01<00:38,  4.22it/s, val_loss=0.1132]
# Validating:   4%|▎         | 6/169 [00:01<00:38,  4.22it/s, val_loss=0.0637]
# Validating:   4%|▍         | 7/169 [00:01<00:38,  4.25it/s, val_loss=0.0637]
# Validating:   4%|▍         | 7/169 [00:01<00:38,  4.25it/s, val_loss=0.0722]
# Validating:   5%|▍         | 8/169 [00:01<00:37,  4.28it/s, val_loss=0.0722]
# Validating:   5%|▍         | 8/169 [00:02<00:37,  4.28it/s, val_loss=0.0505]
# Validating:   5%|▌         | 9/169 [00:02<00:37,  4.30it/s, val_loss=0.0505]
# Validating:   5%|▌         | 9/169 [00:02<00:37,  4.30it/s, val_loss=0.0370]
# Validating:   6%|▌         | 10/169 [00:02<00:36,  4.30it/s, val_loss=0.0370]
# Validating:   6%|▌         | 10/169 [00:02<00:36,  4.30it/s, val_loss=0.0204]
# Validating:   7%|▋         | 11/169 [00:02<00:36,  4.32it/s, val_loss=0.0204]
# Validating:   7%|▋         | 11/169 [00:02<00:36,  4.32it/s, val_loss=0.0974]
# Validating:   7%|▋         | 12/169 [00:02<00:36,  4.33it/s, val_loss=0.0974]
# Validating:   7%|▋         | 12/169 [00:03<00:36,  4.33it/s, val_loss=0.1340]
# Validating:   8%|▊         | 13/169 [00:03<00:35,  4.35it/s, val_loss=0.1340]
# Validating:   8%|▊         | 13/169 [00:03<00:35,  4.35it/s, val_loss=0.1244]
# Validating:   8%|▊         | 14/169 [00:03<00:35,  4.35it/s, val_loss=0.1244]
# Validating:   8%|▊         | 14/169 [00:03<00:35,  4.35it/s, val_loss=0.1570]
# Validating:   9%|▉         | 15/169 [00:03<00:35,  4.35it/s, val_loss=0.1570]
# Validating:   9%|▉         | 15/169 [00:03<00:35,  4.35it/s, val_loss=0.1618]
# Validating:   9%|▉         | 16/169 [00:03<00:35,  4.34it/s, val_loss=0.1618]
# Validating:   9%|▉         | 16/169 [00:04<00:35,  4.34it/s, val_loss=0.1446]
# Validating:  10%|█         | 17/169 [00:04<00:34,  4.35it/s, val_loss=0.1446]
# Validating:  10%|█         | 17/169 [00:04<00:34,  4.35it/s, val_loss=0.0489]
# Validating:  11%|█         | 18/169 [00:04<00:34,  4.35it/s, val_loss=0.0489]
# Validating:  11%|█         | 18/169 [00:04<00:34,  4.35it/s, val_loss=0.0340]
# Validating:  11%|█         | 19/169 [00:04<00:34,  4.36it/s, val_loss=0.0340]
# Validating:  11%|█         | 19/169 [00:04<00:34,  4.36it/s, val_loss=0.1422]
# Validating:  12%|█▏        | 20/169 [00:04<00:34,  4.35it/s, val_loss=0.1422]
# Validating:  12%|█▏        | 20/169 [00:04<00:34,  4.35it/s, val_loss=0.1264]
# Validating:  12%|█▏        | 21/169 [00:04<00:34,  4.35it/s, val_loss=0.1264]
# Validating:  12%|█▏        | 21/169 [00:05<00:34,  4.35it/s, val_loss=0.0863]
# Validating:  13%|█▎        | 22/169 [00:05<00:33,  4.33it/s, val_loss=0.0863]
# Validating:  13%|█▎        | 22/169 [00:05<00:33,  4.33it/s, val_loss=0.0244]
# Validating:  14%|█▎        | 23/169 [00:05<00:33,  4.34it/s, val_loss=0.0244]
# Validating:  14%|█▎        | 23/169 [00:05<00:33,  4.34it/s, val_loss=0.1787]
# Validating:  14%|█▍        | 24/169 [00:05<00:33,  4.34it/s, val_loss=0.1787]
# Validating:  14%|█▍        | 24/169 [00:05<00:33,  4.34it/s, val_loss=0.1061]
# Validating:  15%|█▍        | 25/169 [00:05<00:33,  4.35it/s, val_loss=0.1061]
# Validating:  15%|█▍        | 25/169 [00:06<00:33,  4.35it/s, val_loss=0.0281]
# Validating:  15%|█▌        | 26/169 [00:06<00:32,  4.33it/s, val_loss=0.0281]
# Validating:  15%|█▌        | 26/169 [00:06<00:32,  4.33it/s, val_loss=0.2810]
# Validating:  16%|█▌        | 27/169 [00:06<00:32,  4.33it/s, val_loss=0.2810]
# Validating:  16%|█▌        | 27/169 [00:06<00:32,  4.33it/s, val_loss=0.0537]
# Validating:  17%|█▋        | 28/169 [00:06<00:32,  4.34it/s, val_loss=0.0537]
# Validating:  17%|█▋        | 28/169 [00:06<00:32,  4.34it/s, val_loss=0.1016]
# Validating:  17%|█▋        | 29/169 [00:06<00:32,  4.35it/s, val_loss=0.1016]
# Validating:  17%|█▋        | 29/169 [00:07<00:32,  4.35it/s, val_loss=0.0892]
# Validating:  18%|█▊        | 30/169 [00:07<00:31,  4.35it/s, val_loss=0.0892]
# Validating:  18%|█▊        | 30/169 [00:07<00:31,  4.35it/s, val_loss=0.2173]
# Validating:  18%|█▊        | 31/169 [00:07<00:31,  4.35it/s, val_loss=0.2173]
# Validating:  18%|█▊        | 31/169 [00:07<00:31,  4.35it/s, val_loss=0.1028]
# Validating:  19%|█▉        | 32/169 [00:07<00:31,  4.35it/s, val_loss=0.1028]
# Validating:  19%|█▉        | 32/169 [00:07<00:31,  4.35it/s, val_loss=0.0719]
# Validating:  20%|█▉        | 33/169 [00:07<00:31,  4.36it/s, val_loss=0.0719]
# Validating:  20%|█▉        | 33/169 [00:07<00:31,  4.36it/s, val_loss=0.0202]
# Validating:  20%|██        | 34/169 [00:07<00:30,  4.37it/s, val_loss=0.0202]
# Validating:  20%|██        | 34/169 [00:08<00:30,  4.37it/s, val_loss=0.0586]
# Validating:  21%|██        | 35/169 [00:08<00:30,  4.36it/s, val_loss=0.0586]
# Validating:  21%|██        | 35/169 [00:08<00:30,  4.36it/s, val_loss=0.0357]
# Validating:  21%|██▏       | 36/169 [00:08<00:30,  4.36it/s, val_loss=0.0357]
# Validating:  21%|██▏       | 36/169 [00:08<00:30,  4.36it/s, val_loss=0.0549]
# Validating:  22%|██▏       | 37/169 [00:08<00:30,  4.36it/s, val_loss=0.0549]
# Validating:  22%|██▏       | 37/169 [00:08<00:30,  4.36it/s, val_loss=0.1471]
# Validating:  22%|██▏       | 38/169 [00:08<00:30,  4.36it/s, val_loss=0.1471]
# Validating:  22%|██▏       | 38/169 [00:09<00:30,  4.36it/s, val_loss=0.1637]
# Validating:  23%|██▎       | 39/169 [00:09<00:29,  4.35it/s, val_loss=0.1637]
# Validating:  23%|██▎       | 39/169 [00:09<00:29,  4.35it/s, val_loss=0.0814]
# Validating:  24%|██▎       | 40/169 [00:09<00:29,  4.33it/s, val_loss=0.0814]
# Validating:  24%|██▎       | 40/169 [00:09<00:29,  4.33it/s, val_loss=0.2845]
# Validating:  24%|██▍       | 41/169 [00:09<00:29,  4.35it/s, val_loss=0.2845]
# Epoch 86:  92%|█████████▏| 1245/1350 [05:59<00:26,  3.93it/s, loss=0.0788, lr=0.000003]

# %%
ls data/processed/train/
# Out:
# ls: cannot access 'data/processed/train/': No such file or directory
